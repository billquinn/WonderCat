# %% [markdown]
# # WonderCat Notebook
#
# Brian's Daley Github: https://github.com/uconndxlab/wondercat/wiki/Date-Query-Reference

# %%
# Import necessary libraries.
import re, warnings, sys, os, base64, requests, json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
import networkx as nx

from functions import *
import constants

# # Declare directory.
# abs_dir = Path(__file__).parent
# data = pd.read_csv(abs_dir / 'Data/reading-experiences.csv', sep = ',')

# Call Data from WordPress API
wp_call = read_wordpress_post_with_pagination()

# Reshape wp_call (json) as dataframe.
data = transform_to_dataframe(wp_call)

data.head()
# Out:
#     id  author                 date                            benefit  \
# 0  710       1  2025-01-24T19:18:33  xxx-I need to enter something new
# 1  474       4  2025-01-15T19:26:15                     Bias Reduction
# 2  362       5  2025-01-09T21:27:04                              Faith
# 3  364       5  2025-01-09T20:56:26                         Generosity
# 4  363       5  2025-01-09T20:55:14                              Faith
#
#                           experience                         technology  \
# 0  xxx-I need to enter something new  xxx-I need to enter something new
# 1                         Alienation         Almighty Heart + Soliloquy
# 2                             Wonder                             Enigma
# 3                             Wonder                            Stretch
# 4                             Wonder                         Plot Twist
#
#            title       QID
# 0        testing  Q3456789
# 1           Test   Q223880
# 2  Mystery Plays   Q240911
# 3        Oedipus   Q148643
# 4        Oedipus   Q148643

# %% [markdown]
# ## Networks

# %%
# %%time

G = create_network_graph(data, 'author', 'benefit', 'experience', 'title')
# Out:
# CPU times: user 317 ms, sys: 21.5 ms, total: 339 ms
# Wall time: 412 ms

# %%
# %%time

# Create network visualization with Plotly.
def create_network_visualization(graph_object):
    node_traces = create_node_traces(graph_object)
    edge_traces = create_edge_traces(graph_object)

    fig = px.line(
        edge_traces, x = 'x', y = 'y'
    ).update_traces(line_color='#888')

    node_trace = px.scatter(
        node_traces, x="x", y="y", 
        color="type", size='size', opacity = 1,
        hover_data=['text']
    ).data

    fig.add_traces(node_trace)

    return fig

create_network_visualization(G)
# Out:
# CPU times: user 752 ms, sys: 564 ms, total: 1.32 s
# Wall time: 5.23 s
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/Library/Python/3.13/lib/python/site-packages/IPython/core/formatters.py:984, in IPythonDisplayFormatter.__call__(self, obj)
#     982 method = get_real_method(obj, self.print_method)
#     983 if method is not None:
# --> 984     method()
#     985     return True
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/plotly/basedatatypes.py:832, in BaseFigure._ipython_display_(self)
#     829 import plotly.io as pio
#     831 if pio.renderers.render_on_display and pio.renderers.default:
# --> 832     pio.show(self)
#     833 else:
#     834     print(repr(self))
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/plotly/io/_renderers.py:394, in show(fig, renderer, validate, **kwargs)
#     389         raise ValueError(
#     390             "Mime type rendering requires ipython but it is not installed"
#     391         )
#     393     if not nbformat or Version(nbformat.__version__) < Version("4.2.0"):
# --> 394         raise ValueError(
#     395             "Mime type rendering requires nbformat>=4.2.0 but it is not installed"
#     396         )
#     398     ipython_display.display(bundle, raw=True)
#     400 # external renderers
#
# ValueError: Mime type rendering requires nbformat>=4.2.0 but it is not installed
# Figure({
#     'data': [{'hovertemplate': 'x=%{x}<br>y=%{y}<extra></extra>',
#               'legendgroup': '',
#               'line': {'color': '#888', 'dash': 'solid'},
#               'marker': {'symbol': 'circle'},
#               'mode': 'lines',
#               'name': '',
#               'orientation': 'v',
#               'showlegend': False,
#               'type': 'scatter',
#               'x': array([ 0.00013233, -0.01361577,         nan, ..., -0.07616096, -0.08209036,
#                                   nan], shape=(969,)),
#               'xaxis': 'x',
#               'y': array([-0.00081388, -0.09377485,         nan, ...,  0.14185539,  0.24678261,
#                                   nan], shape=(969,)),
#               'yaxis': 'y'},
#              {'customdata': array([[5],
#                                    [1],
#                                    [4]], dtype=object),
#               'hovertemplate': ('type=author<br>x=%{x}<br>y=%{y' ... '{customdata[0]}<extra></extra>'),
#               'legendgroup': 'author',
#               'marker': {'color': '#636efa',
#                          'opacity': 1,
#                          'size': array([64, 14,  2]),
#                          'sizemode': 'area',
#                          'sizeref': np.float64(0.16),
#                          'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'author',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'scatter',
#               'x': array([ 0.00013233, -0.04932962, -0.00438065]),
#               'xaxis': 'x',
#               'y': array([-0.00081388,  0.01563648, -0.15331912]),
#               'yaxis': 'y'},
#              {'customdata': array([['Peace of Mind'],
#                                    ['Intimacy'],
#                                    ['Innovative Thinking'],
#                                    ['Self-Scrutiny'],
#                                    ['Forgiveness'],
#                                    ['Purpose'],
#                                    ['Vigilance'],
#                                    ['Unrealistic Romantic Expectations'],
#                                    ['Expanded Inner List of Cultural Norms'],
#                                    ['Creative Breakthrough'],
#                                    ['Tend and Befriend'],
#                                    ['Creativity'],
#                                    ['Healthy Grief'],
#                                    ['Realistic Appreciation of Love'],
#                                    ["Humility about One's Ideas"],
#                                    ['Bias Reduction'],
#                                    ['Obedience'],
#                                    ['Community'],
#                                    ['Anxiety'],
#                                    ['Healing'],
#                                    ['Cognitive Flexibility'],
#                                    ['Belief'],
#                                    ['Gratitude'],
#                                    ['Gratitude without Inferiority'],
#                                    ['Catastrophizing'],
#                                    ['Faith'],
#                                    ['Detached Self-Awareness'],
#                                    ['Generosity'],
#                                    ["Humility about One's Nature"]], dtype=object),
#               'hovertemplate': ('type=benefit<br>x=%{x}<br>y=%{' ... '{customdata[0]}<extra></extra>'),
#               'legendgroup': 'benefit',
#               'marker': {'color': '#EF553B',
#                          'opacity': 1,
#                          'size': array([10,  8,  4,  6,  4,  4,  8,  4,  4,  4,  6,  4,  4,  6,  4,  8,  4,  8,
#                                          4,  8,  6,  6,  6,  4,  4,  4,  4,  4,  4]),
#                          'sizemode': 'area',
#                          'sizeref': np.float64(0.16),
#                          'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'benefit',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'scatter',
#               'x': array([-0.01361577, -0.08196037, -0.0217854 , -0.09313211,  0.06814402,
#                            0.0915458 ,  0.0087155 , -0.06350013,  0.06091411,  0.07135372,
#                           -0.05108708,  0.0177146 ,  0.04731088,  0.0918714 , -0.11495405,
#                           -0.02450681, -0.03826004, -0.05179671, -0.00982424, -0.03034954,
#                           -0.12000812,  0.06407289,  0.06319463, -0.06835749,  0.02324245,
#                            0.10008771,  0.08878207,  0.10647285, -0.03093446]),
#               'xaxis': 'x',
#               'y': array([-0.09377485, -0.04009885, -0.09048282,  0.00976001,  0.07056708,
#                           -0.05718179,  0.0596207 ,  0.08058633, -0.06721002,  0.03613084,
#                            0.04498896,  0.10621981,  0.04894022, -0.02579502, -0.0047724 ,
#                           -0.09613791,  0.09845116, -0.08081185,  0.12243916,  0.10979913,
#                           -0.03858204,  0.12328217,  0.03368006,  0.02994883, -0.09729046,
#                           -0.03742918, -0.14314941, -0.04711814, -0.08678299]),
#               'yaxis': 'y'},
#              {'customdata': array([['Connection'],
#                                    ['Love'],
#                                    ['Thinking "What If?"'],
#                                    ['Alienation'],
#                                    ['Empathy'],
#                                    ['Curiosity'],
#                                    ['Paranoia'],
#                                    ['Gratification'],
#                                    ['Self-Acceptance'],
#                                    ['Self-Irony'],
#                                    ['Relearning'],
#                                    ['Identification'],
#                                    ['Courage'],
#                                    ['Mind Wandering'],
#                                    ['Tranquility'],
#                                    ['Acceptance of Loss'],
#                                    ['Being Wrong'],
#                                    ['Generous Love'],
#                                    ['Suspended Judgment'],
#                                    ['Awe'],
#                                    ['Righteousness'],
#                                    ['Resilience'],
#                                    ['Optimism'],
#                                    ['Superiority'],
#                                    ['Empowerment'],
#                                    ['Ready to Grow'],
#                                    ['Wonder'],
#                                    ['Moral Omniscience'],
#                                    ['Released Emotion Brake'],
#                                    ['Self-Trust'],
#                                    ['Immersion'],
#                                    ['Togetherness'],
#                                    ['Double Identification'],
#                                    ['Confusion'],
#                                    ['Nimbleness'],
#                                    ['Distress'],
#                                    ['Dissociation'],
#                                    ['Eustress'],
#                                    ['Self-Love'],
#                                    ['Existential Nausea'],
#                                    ['Self-Efficacy'],
#                                    ['Sober Uplift'],
#                                    ['Skepticism'],
#                                    ['xxx-I need to enter something new']], dtype=object),
#               'hovertemplate': ('type=experience<br>x=%{x}<br>y' ... '{customdata[0]}<extra></extra>'),
#               'legendgroup': 'experience',
#               'marker': {'color': '#00cc96',
#                          'opacity': 1,
#                          'size': array([20, 32, 34, 32, 28, 26, 24, 28, 20, 26, 18, 20, 18, 18, 16, 12, 14, 14,
#                                         16, 12, 12, 14, 10, 10, 14,  8,  8, 10,  6,  6,  6,  4,  4,  6,  4,  4,
#                                          4,  4,  8,  4,  4,  4,  4,  4]),
#                          'sizemode': 'area',
#                          'sizeref': np.float64(0.16),
#                          'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'experience',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'scatter',
#               'x': array([ 0.08705216, -0.15903816, -0.04279846, -0.18072844,  0.14004023,
#                            0.18732044,  0.01091752, -0.12680182,  0.12350248, -0.01372679,
#                            0.1426    ,  0.18280386, -0.09449373,  0.03776531, -0.06479843,
#                            0.09762729, -0.2275513 ,  0.18766875,  0.00605768, -0.07451719,
#                           -0.12293091,  0.0271429 ,  0.10587365, -0.0182034 , -0.12095305,
#                           -0.22942771,  0.1956292 ,  0.04676318, -0.06761148, -0.22210937,
#                            0.12588273,  0.19006035,  0.23491066, -0.09528638, -0.2645845 ,
#                            0.13082465,  0.05474759,  0.17331235, -0.1536955 , -0.2514636 ,
#                            0.02822008,  0.13410112,  0.07906568, -0.07616096]),
#               'xaxis': 'x',
#               'y': array([ 0.00680634, -0.08427835, -0.1814957 ,  0.01859137,  0.1424047 ,
#                           -0.11363626,  0.13442726,  0.16266837, -0.1343276 , -0.16670631,
#                            0.07444681,  0.032187  ,  0.08932887,  0.21154065, -0.19889089,
#                            0.09506932, -0.00812184, -0.02835783, -0.20148763,  0.19885956,
#                           -0.14641696, -0.02523854,  0.01450716,  0.24192753,  0.05822983,
#                           -0.0720728 , -0.06852797, -0.18502986,  0.2318156 ,  0.14185422,
#                            0.2340301 ,  0.11979241, -0.00221612, -0.16487548, -0.07447161,
#                            0.26098091, -0.2186997 , -0.27193491, -0.03328568,  0.13270408,
#                            0.20717226, -0.14162693, -0.06214792,  0.14185539]),
#               'yaxis': 'y'},
#              {'customdata': array([['Hamlet'],
#                                    ['Oedipus'],
#                                    ["Sappho's Lyrics"],
#                                    ...,
#                                    ['Saturday'],
#                                    ['Pilgrimage'],
#                                    ['Mrs. Dalloway']], shape=(225, 1), dtype=object),
#               'hovertemplate': ('type=title<br>x=%{x}<br>y=%{y}' ... '{customdata[0]}<extra></extra>'),
#               'legendgroup': 'title',
#               'marker': {'color': '#ab63fa',
#                          'opacity': 1,
#                          'size': array([4, 2, 2, ..., 2, 2, 2], shape=(225,)),
#                          'sizemode': 'area',
#                          'sizeref': np.float64(0.16),
#                          'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'title',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'scatter',
#               'x': array([ 0.14025958,  0.2587905 , -0.19822222, ..., -0.08111566, -0.10754651,
#                           -0.12284109], shape=(225,)),
#               'xaxis': 'x',
#               'y': array([ 0.09377472, -0.09105329, -0.11753124, ..., -0.32052187, -0.30877975,
#                           -0.30836839], shape=(225,)),
#               'yaxis': 'y'}],
#     'layout': {'legend': {'tracegroupgap': 0},
#                'margin': {'t': 60},
#                'template': '...',
#                'xaxis': {'anchor': 'y', 'domain': [0.0, 1.0], 'title': {'text': 'x'}},
#                'yaxis': {'anchor': 'x', 'domain': [0.0, 1.0], 'title': {'text': 'y'}}}
# })

# %% [markdown]
# ## Call WordPress API

# %%
# %%time

# Import credentials
WP_USER = constants.WP_USER
WP_KEY = constants.WP_KEY
wp_credentials = WP_USER + WP_KEY
wp_credentials = WP_USER + WP_KEY
wp_token = base64.b64encode(wp_credentials.encode())
wp_header = {'Authorization': 'Basic ' + wp_token.decode('utf-8')}

# response = requests.get('https://env-1120817.us.reclaim.cloud/wp-json/wp/v2/experience?page=1&per_page=100', headers = wp_header)
# print (response)
# print (response.json())

def read_wordpress_posts():
    api_url = 'https://env-1120817.us.reclaim.cloud/wp-json/wp/v2/user-experience'
    response = requests.get(api_url)
    response_json = response.json()
    print(response_json)

def get_total_pagecount():
    api_url = 'https://env-1120817.us.reclaim.cloud/wp-json/wp/v2/user-experience?page=1&per_page=100'
    response = requests.get(api_url)
    pages_count = response.headers['X-WP-TotalPages']
    return int(pages_count)

def read_wordpress_post_with_pagination():
    total_pages = get_total_pagecount()
    current_page = 1
    all_page_items_json = []
    while current_page <= total_pages:
        api_url = f"https://env-1120817.us.reclaim.cloud/wp-json/wp/v2/user-experience?page={current_page}&per_page=100"
        page_items = requests.get(api_url)
        page_items_json = page_items.json()
        all_page_items_json.extend(page_items_json)
        current_page = current_page + 1
    return all_page_items_json

wp_data = read_wordpress_post_with_pagination()
wp_data[0]
# Out:
# CPU times: user 312 ms, sys: 90.3 ms, total: 402 ms
# Wall time: 5.19 s
# {'id': 474,
#  'date': '2025-01-15T19:26:15',
#  'date_gmt': '2025-01-15T19:26:15',
#  'guid': {'rendered': 'https://env-1120817.us.reclaim.cloud/?post_type=experience&#038;p=474'},
#  'modified': '2025-01-15T19:42:40',
#  'modified_gmt': '2025-01-15T19:42:40',
#  'slug': 'brian-test',
#  'status': 'publish',
#  'type': 'user-experience',
#  'link': 'https://env-1120817.us.reclaim.cloud/user-experience/brian-test/',
#  'title': {'rendered': 'Brian Test'},
#  'content': {'rendered': '', 'protected': False},
#  'author': 4,
#  'featured_media': 458,
#  'template': '',
#  'meta': {'_acf_changed': True},
#  'benefit': [{'id': 179,
#    'name': 'Bias Reduction',
#    'slug': 'bias-reduction',
#    'description': ''}],
#  'experience': [{'id': 83,
#    'name': 'Alienation',
#    'slug': 'alienation',
#    'description': 'Distrusting yourself. Alientation is the inverse of paranoia, which involves distrusting someone or something outside of yourself.\r\n\r\nAlso called: Distrust\r\n\r\n'}],
#  'technology': [{'id': 114,
#    'name': 'Almighty Heart + Soliloquy',
#    'slug': 'almighty-heart-plus-soliloquy',
#    'description': 'The combination of the secret discloser (a narrative technology in which a narrator shares an intimate secret about a character) with wish fulfillment (a plot technology that shows a character getting everything they want) and soliloquy (a character who reveals a conflict that you have experienced, prompting identification)\r\n'}],
#  'user-proposed-benefit': [],
#  'user-proposed-experience': [],
#  'user-proposed-technology': [],
#  'acf': {'title_of_creative_work': 'Test',
#   'in_wikidata': 'yes',
#   'wikidata-qid': 'Q223880',
#   'wikidata': {'entities': {'Q223880': {'pageid': 218566,
#      'ns': 0,
#      'title': 'Q223880',
#      'lastrevid': 2268791354,
#      'modified': '2024-11-01T20:50:46Z',
#      'type': 'item',
#      'id': 'Q223880',
#      'labels': {'zh-hans': {'language': 'zh-hans', 'value': 'u7231u739b'},
#       'zh-hant': {'language': 'zh-hant', 'value': 'u611bu746a'},
#       'zh-hk': {'language': 'zh-hk', 'value': 'u611bu746a'},
#       'zh-cn': {'language': 'zh-cn', 'value': 'u7231u739b'},
#       'zh-sg': {'language': 'zh-sg', 'value': 'u7231u739b'},
#       'zh-tw': {'language': 'zh-tw', 'value': 'u611bu746a'},
#       'pl': {'language': 'pl', 'value': 'Emma'},
#       'he': {'language': 'he', 'value': 'u05d0u05deu05d4'},
#       'ko': {'language': 'ko', 'value': 'uc5e0ub9c8'},
#       'fr': {'language': 'fr', 'value': 'Emma'},
#       'es': {'language': 'es', 'value': 'Emma'},
#       'hu': {'language': 'hu', 'value': 'Emma'},
#       'it': {'language': 'it', 'value': 'Emma'},
#       'de': {'language': 'de', 'value': 'Emma'},
#       'ja': {'language': 'ja', 'value': 'u30a8u30de'},
#       'vi': {'language': 'vi', 'value': 'Emma'},
#       'el': {'language': 'el', 'value': 'u0388u03bcu03bcu03b1'},
#       'en': {'language': 'en', 'value': 'Emma'},
#       'sv': {'language': 'sv', 'value': 'Emma'},
#       'ar': {'language': 'ar', 'value': 'u0625u064au0645u0627'},
#       'nl': {'language': 'nl', 'value': 'Emma'},
#       'hi': {'language': 'hi', 'value': 'u090fu092eu093e'},
#       'pt': {'language': 'pt', 'value': 'Emma'},
#       'ru': {'language': 'ru', 'value': 'u042du043cu043cu0430'},
#       'ca': {'language': 'ca', 'value': 'Emma'},
#       'fi': {'language': 'fi', 'value': 'Emma'},
#       'uk': {'language': 'uk', 'value': 'u0415u043cu043cu0430'},
#       'cy': {'language': 'cy', 'value': 'Emma'},
#       'sl': {'language': 'sl', 'value': 'Emma'},
#       'cs': {'language': 'cs', 'value': 'Emma'},
#       'bg': {'language': 'bg', 'value': 'u0415u043cu0430'},
#       'fa': {'language': 'fa', 'value': 'u0627u0645u0627'},
#       'te': {'language': 'te', 'value': 'u0c0eu0c2eu0c4du0c2eu0c3e'},
#       'da': {'language': 'da', 'value': 'Emma'},
#       'zh': {'language': 'zh', 'value': 'u611bu746a'},
#       'id': {'language': 'id', 'value': 'Emma'},
#       'nb': {'language': 'nb', 'value': 'Emma'},
#       'hy': {'language': 'hy', 'value': 'u0537u0574u0574u0561'},
#       'af': {'language': 'af', 'value': 'Emma'},
#       'bn': {'language': 'bn', 'value': 'u098fu09aeu09be'},
#       'kn': {'language': 'kn', 'value': 'u0c8eu0caeu0ccdu0caeu0cbe'},
#       'ka': {'language': 'ka', 'value': 'u10d4u10dbu10d0'},
#       'eo': {'language': 'eo', 'value': 'Emma'},
#       'ky': {'language': 'ky', 'value': 'u042du043cu043cu0430'},
#       'tr': {'language': 'tr', 'value': 'Emma'},
#       'et': {'language': 'et', 'value': 'Emma'},
#       'ml': {'language': 'ml', 'value': 'u0d0eu0d2eu0d4du0d2e'},
#       'ro': {'language': 'ro', 'value': 'Emma'},
#       'jv': {'language': 'jv', 'value': 'Emma'},
#       'su': {'language': 'su', 'value': 'Emma'},
#       'ga': {'language': 'ga', 'value': 'Emma'},
#       'br': {'language': 'br', 'value': 'Emma'},
#       'sr': {'language': 'sr', 'value': 'u0415u043cu0430'},
#       'ast': {'language': 'ast', 'value': 'Emma'},
#       'be': {'language': 'be', 'value': 'u042du043cu0430'},
#       'uz': {'language': 'uz', 'value': 'Emma (roman)'}},
#      'descriptions': {'it': {'language': 'it',
#        'value': 'romanzo scritto da Jane Austen'},
#       'he': {'language': 'he',
#        'value': "u05e8u05d5u05deu05df u05deu05d0u05ea u05d2'u05d9u05d9u05df u05d0u05d5u05e1u05d8u05df"},
#       'fr': {'language': 'fr', 'value': 'roman de Jane Austen'},
#       'en': {'language': 'en', 'value': '1815 novel by Jane Austen'},
#       'nl': {'language': 'nl', 'value': 'roman van Jane Austen (1815)'},
#       'de': {'language': 'de',
#        'value': 'Gesellschaftsroman von Jane Austen (1815)'},
#       'ar': {'language': 'ar',
#        'value': 'u0631u0648u0627u064au0629 u0645u0646 u062au0623u0644u064au0641 u062cu0627u064au0646 u0623u0648u0633u062au0646'},
#       'pt': {'language': 'pt',
#        'value': 'Livro Romu00e2ntico da literatura inglesa'},
#       'ka': {'language': 'ka',
#        'value': 'u10efu10d4u10d8u10dc u10ddu10e1u10e2u10d8u10dcu10d8u10e1 u10dcu10ddu10d5u10d4u10dau10d0'},
#       'eo': {'language': 'eo', 'value': 'romano far Jane Austen'},
#       'cs': {'language': 'cs',
#        'value': 'romu00e1n od anglicku00e9 spisovatelky Jane Austenovu00e9'},
#       'br': {'language': 'br', 'value': 'romant'},
#       'ko': {'language': 'ko',
#        'value': '1815ub144 ucd9cuac04ub41c uc81cuc778 uc624uc2a4ud2f4uc758 uc18cuc124'},
#       'es': {'language': 'es', 'value': 'novela de Jane Austen'},
#       'tr': {'language': 'tr',
#        'value': "Jane Austen'u0131n 1815 tarihli romanu0131"},
#       'id': {'language': 'id', 'value': 'novel tahun 1815 karya Jane Austen'},
#       'ru': {'language': 'ru',
#        'value': 'u0440u043eu043cu0430u043d u0414u0436u0435u0439u043d u041eu0441u0442u0438u043d'},
#       'ja': {'language': 'ja',
#        'value': 'u30b8u30a7u30a4u30f3u30fbu30aau30fcu30b9u30c6u30a3u30f3u306eu5c0fu8aac'},
#       'ro': {'language': 'ro', 'value': 'roman'},
#       'ast': {'language': 'ast', 'value': 'novela de Jane Austen'},
#       'be': {'language': 'be',
#        'value': 'u0440u0430u043cu0430u043d u0414u0436u044du0439u043d u041eu0441u0446u0456u043d 1815 u0433u043eu0434u0430'},
#       'ca': {'language': 'ca', 'value': 'Novelu00b7la de Jane Austen'},
#       'vi': {'language': 'vi',
#        'value': 'tiu1ec3u thuyu1ebft cu1ee7a Jane Austen'},
#       'fi': {'language': 'fi', 'value': 'Jane Austenin romaani vuodelta 1815'},
#       'uz': {'language': 'uz', 'value': 'Jane Austen qalamiga mansub roman'}},
#      'aliases': {'ko': [{'language': 'ko', 'value': 'uc5d0ub9c8'}],
#       'nl': [{'language': 'nl', 'value': 'Emma (roman)'}]},
#      'claims': {'P50': [{'mainsnak': {'snaktype': 'value',
#          'property': 'P50',
#          'hash': 'fd5d824e81e9ce82aace4ad5faa8a06a71a91032',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 36322,
#            'id': 'Q36322'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'},
#         'type': 'statement',
#         'id': 'Q223880$98F30FF1-7B5F-40B4-9F33-475718C6C865',
#         'rank': 'normal'}],
#       'P123': [{'mainsnak': {'snaktype': 'value',
#          'property': 'P123',
#          'hash': 'fd5d26dc6c6dc0bbb071432f65843c8ff8c2d72b',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 1232629,
#            'id': 'Q1232629'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'},
#         'type': 'statement',
#         'id': 'q223880$36A54DEF-227B-4B43-BEE3-9092F746E6EC',
#         'rank': 'normal',
#         'references': [{'hash': 'fa278ebfc458360e5aed63d5058cca83c46134f1',
#           'snaks': {'P143': [{'snaktype': 'value',
#              'property': 'P143',
#              'hash': 'e4f6d9441d0600513c4533c672b5ab472dc73694',
#              'datavalue': {'value': {'entity-type': 'item',
#                'numeric-id': 328,
#                'id': 'Q328'},
#               'type': 'wikibase-entityid'},
#              'datatype': 'wikibase-item'}]},
#           'snaks-order': ['P143']}]}],
#       'P155': [{'mainsnak': {'snaktype': 'value',
#          'property': 'P155',
#          'hash': 'e2b2ad646fc747e875784b59fc31835f13f9f233',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 469690,
#            'id': 'Q469690'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'},
#         'type': 'statement',
#         'id': 'q223880$2C156399-DC89-4480-A4DE-0008A6CD1018',
#         'rank': 'normal',
#         'references': [{'hash': 'fa278ebfc458360e5aed63d5058cca83c46134f1',
#           'snaks': {'P143': [{'snaktype': 'value',
#              'property': 'P143',
#              'hash': 'e4f6d9441d0600513c4533c672b5ab472dc73694',
#              'datavalue': {'value': {'entity-type': 'item',
#                'numeric-id': 328,
#                'id': 'Q328'},
#               'type': 'wikibase-entityid'},
#              'datatype': 'wikibase-item'}]},
#           'snaks-order': ['P143']}]}],
#       'P156': [{'mainsnak': {'snaktype': 'value',
#          'property': 'P156',
#          'hash': '10043eb2ad1a1d4894d87bf2144388278db1d788',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 477508,
#            'id': 'Q477508'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'},
#         'type': 'statement',
#         'id': 'q223880$72836DA7-91EB-4727-AFC1-52786C7E0689',
#         'rank': 'normal',
#         'references': [{'hash': 'fa278ebfc458360e5aed63d5058cca83c46134f1',
#           'snaks': {'P143': [{'snaktype': 'value',
#              'property': 'P143',
#              'hash': 'e4f6d9441d0600513c4533c672b5ab472dc73694',
#              'datavalue': {'value': {'entity-type': 'item',
#                'numeric-id': 328,
#                'id': 'Q328'},
#               'type': 'wikibase-entityid'},
#              'datatype': 'wikibase-item'}]},
#           'snaks-order': ['P143']}]}],
#       'P373': [{'mainsnak': {'snaktype': 'value',
#          'property': 'P373',
#          'hash': 'd04f5f5e3b4cbc8ed6642cc87c8ccae5d2f989a1',
#          'datavalue': {'value': 'Emma by Jane Austen', 'type': 'string'},
#          'datatype': 'string'},
#         'type': 'statement',
#         'id': 'q223880$69A2A68A-293C-47EC-804A-253DC128107C',
#         'rank': 'normal'}],
#       'P31': [{'mainsnak': {'snaktype': 'value',
#          'property': 'P31',
#          'hash': '5963e3cad5eee4ae1cffbefbac15327800b9a7e6',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 7725634,
#            'id': 'Q7725634'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'},
#         'type': 'statement',
#         'id': 'Q223880$AA230E54-3649-456D-8DC5-FC8C13A1A0F7',
#         'rank': 'normal',
#         'references': [{'hash': 'fa278ebfc458360e5aed63d5058cca83c46134f1',
#           'snaks': {'P143': [{'snaktype': 'value',
#              'property': 'P143',
#              'hash': 'e4f6d9441d0600513c4533c672b5ab472dc73694',
#              'datavalue': {'value': {'entity-type': 'item',
#                'numeric-id': 328,
#                'id': 'Q328'},
#               'type': 'wikibase-entityid'},
#              'datatype': 'wikibase-item'}]},
#           'snaks-order': ['P143']}]}],
#       'P136': [{'mainsnak': {'snaktype': 'value',
#          'property': 'P136',
#          'hash': 'c8df8c66105a5b9b98e31258cc5794e4c2c38762',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 19765983,
#            'id': 'Q19765983'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'},
#         'type': 'statement',
#         'id': 'Q223880$B97895DA-F2DA-4BD9-8C81-69D2AAE9CAE6',
#         'rank': 'normal'}],
#       'P646': [{'mainsnak': {'snaktype': 'value',
#          'property': 'P646',
#          'hash': '2d47fbd60609efeba10b44c5efc01b3292ecc595',
#          'datavalue': {'value': '/m/0frym', 'type': 'string'},
#          'datatype': 'external-id'},
#         'type': 'statement',
#         'id': 'Q223880$210E5A36-A192-41C4-B5A5-645099045B69',
#         'rank': 'normal',
#         'references': [{'hash': '2b00cb481cddcac7623114367489b5c194901c4a',
#           'snaks': {'P248': [{'snaktype': 'value',
#              'property': 'P248',
#              'hash': 'a94b740202b097dd33355e0e6c00e54b9395e5e0',
#              'datavalue': {'value': {'entity-type': 'item',
#                'numeric-id': 15241312,
#                'id': 'Q15241312'},
#               'type': 'wikibase-entityid'},
#              'datatype': 'wikibase-item'}],
#            'P577': [{'snaktype': 'value',
#              'property': 'P577',
#              'hash': 'fde79ecb015112d2f29229ccc1ec514ed3e71fa2',
#              'datavalue': {'value': {'time': '+2013-10-28T00:00:00Z',
#                'timezone': 0,
#                'before': 0,
#                'after': 0,
#                'precision': 11,
#                'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#               'type': 'time'},
#              'datatype': 'time'}]},
#           'snaks-order': ['P248', 'P577']}]}],
#       'P268': [{'mainsnak': {'snaktype': 'value',
#          'property': 'P268',
#          'hash': '8a992dfcb5c413eaf8172033b1f277e8ae7a8686',
#          'datavalue': {'value': '119430968', 'type': 'string'},
#          'datatype': 'external-id'},
#         'type': 'statement',
#         'id': 'Q223880$5DF34535-A5F1-49FE-91C1-2F61ED667C80',
#         'rank': 'normal'}],
#       'P18': [{'mainsnak': {'snaktype': 'value',
#          'property': 'P18',
#          'hash': '3e2229de1271849013f7938df7a1538fee0dded0',
#          'datavalue': {'value': 'EmmaTitlePage.jpg', 'type': 'string'},
#          'datatype': 'commonsMedia'},
#         'type': 'statement',
#         'id': 'Q223880$ED80BECC-55F5-4BB2-A11C-CBD74264C250',
#         'rank': 'normal',
#         'references': [{'hash': 'fa278ebfc458360e5aed63d5058cca83c46134f1',
#           'snaks': {'P143': [{'snaktype': 'value',
#              'property': 'P143',
#              'hash': 'e4f6d9441d0600513c4533c672b5ab472dc73694',
#              'datavalue': {'value': {'entity-type': 'item',
#                'numeric-id': 328,
#                'id': 'Q328'},
#               'type': 'wikibase-entityid'},
#              'datatype': 'wikibase-item'}]},
#           'snaks-order': ['P143']}]}],
#       'P577': [{'mainsnak': {'snaktype': 'value',
#          'property': 'P577',
#          'hash': '16cd16d71560d408b9aab6898c8c15dc40cc81e5',
#          'datavalue': {'value': {'time': '+1815-12-23T00:00:00Z',
#            'timezone': 0,
#            'before': 0,
#            'after': 0,
#            'precision': 11,
#            'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#           'type': 'time'},
#          'datatype': 'time'},
#         'type': 'statement',
#         'id': 'Q223880$4AFF4B99-BC4E-493B-AD8D-101FAB0A5440',
#         'rank': 'normal',
#         'references': [{'hash': 'fa278ebfc458360e5aed63d5058cca83c46134f1',
#           'snaks': {'P143': [{'snaktype': 'value',
#              'property': 'P143',
#              'hash': 'e4f6d9441d0600513c4533c672b5ab472dc73694',
#              'datavalue': {'value': {'entity-type': 'item',
#                'numeric-id': 328,
#                'id': 'Q328'},
#               'type': 'wikibase-entityid'},
#              'datatype': 'wikibase-item'}]},
#           'snaks-order': ['P143']}]}],
#       'P840': [{'mainsnak': {'snaktype': 'value',
#          'property': 'P840',
#          'hash': '6154681599238bee61a26f0c9390563e14566a9f',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 1134643,
#            'id': 'Q1134643'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'},
#         'type': 'statement',
#         'id': 'Q223880$EF239960-1B06-4AF0-B8C3-03C40E94DB0E',
#         'rank': 'normal',
#         'references': [{'hash': 'cf7e87ff0ab4e3218527b5ce611c4f0949d6744e',
#           'snaks': {'P648': [{'snaktype': 'value',
#              'property': 'P648',
#              'hash': 'ba49a722313cb4c055c97ffa2fa7e931117c98d1',
#              'datavalue': {'value': 'OL66513W', 'type': 'string'},
#              'datatype': 'external-id'}]},
#           'snaks-order': ['P648']}]}],
#       'P910': [{'mainsnak': {'snaktype': 'value',
#          'property': 'P910',
#          'hash': '489cf884094ff7fcc6b4becbb95b6ea7172a6e37',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 10016634,
#            'id': 'Q10016634'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'},
#         'type': 'statement',
#         'id': 'Q223880$F5A5B82A-1F4D-44A1-A2A5-DEF4B9240984',
#         'rank': 'normal',
#         'references': [{'hash': 'd4bd87b862b12d99d26e86472d44f26858dee639',
#           'snaks': {'P143': [{'snaktype': 'value',
#              'property': 'P143',
#              'hash': 'f30cbd35620c4ea6d0633aaf0210a8916130469b',
#              'datavalue': {'value': {'entity-type': 'item',
#                'numeric-id': 8447,
#                'id': 'Q8447'},
#               'type': 'wikibase-entityid'},
#              'datatype': 'wikibase-item'}]},
#           'snaks-order': ['P143']}]}],
#       'P747': [{'mainsnak': {'snaktype': 'value',
#          'property': 'P747',
#          'hash': '35f7fd1e74ff12177aa1009156880af8e18cc629',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 17357316,
#            'id': 'Q17357316'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'},
#         'type': 'statement',
#         'id': 'Q223880$02EC8DF3-85B5-4AE5-9DF6-968F43A97116',
#         'rank': 'normal'},
#        {'mainsnak': {'snaktype': 'value',
#          'property': 'P747',
#          'hash': '2942c27d53f0cb7ab6567fd1f153cc313d5453e9',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 83699540,
#            'id': 'Q83699540'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'},
#         'type': 'statement',
#         'id': 'Q223880$73ffcafa-450e-21b5-c7e3-e1fc238bb52f',
#         'rank': 'normal'},
#        {'mainsnak': {'snaktype': 'value',
#          'property': 'P747',
#          'hash': 'f9555b496c44adb8368f6a8f68cc856323122c78',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 117279952,
#            'id': 'Q117279952'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'},
#         'type': 'statement',
#         'qualifiers': {'P407': [{'snaktype': 'value',
#            'property': 'P407',
#            'hash': '3ac65ea2842129be26801ca316a37281bc5f5e93',
#            'datavalue': {'value': {'entity-type': 'item',
#              'numeric-id': 9299,
#              'id': 'Q9299'},
#             'type': 'wikibase-entityid'},
#            'datatype': 'wikibase-item'}],
#          'P577': [{'snaktype': 'value',
#            'property': 'P577',
#            'hash': '30acf3f5e021ae65e70b1bb6f8d14d5dd06513f5',
#            'datavalue': {'value': {'time': '+1978-00-00T00:00:00Z',
#              'timezone': 0,
#              'before': 0,
#              'after': 0,
#              'precision': 9,
#              'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#             'type': 'time'},
#            'datatype': 'time'}]},
#         'qualifiers-order': ['P407', 'P577'],
#         'id': 'Q223880$10BD7672-8E13-4DF1-9548-EA331FF7A547',
#         'rank': 'normal'},
#        {'mainsnak': {'snaktype': 'value',
#          'property': 'P747',
#          'hash': '9272004734e1cff34ac662cb168002f06c46aa9a',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 117281005,
#            'id': 'Q117281005'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'},
#         'type': 'statement',
#         'qualifiers': {'P407': [{'snaktype': 'value',
#            'property': 'P407',
#            'hash': '3ac65ea2842129be26801ca316a37281bc5f5e93',
#            'datavalue': {'value': {'entity-type': 'item',
#              'numeric-id': 9299,
#              'id': 'Q9299'},
#             'type': 'wikibase-entityid'},
#            'datatype': 'wikibase-item'}],
#          'P577': [{'snaktype': 'value',
#            'property': 'P577',
#            'hash': 'de9973bce69e1e4c53708afb409e15dec518b326',
#            'datavalue': {'value': {'time': '+2013-00-00T00:00:00Z',
#              'timezone': 0,
#              'before': 0,
#              'after': 0,
#              'precision': 9,
#              'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#             'type': 'time'},
#            'datatype': 'time'}]},
#         'qualifiers-order': ['P407', 'P577'],
#         'id': 'Q223880$4C673429-00EA-4EEC-B2EE-51EDC549EE44',
#         'rank': 'normal'}],
#       'P2034': [{'mainsnak': {'snaktype': 'value',
#          'property': 'P2034',
#          'hash': '738e367432c07c7c3014213ae031656efdc3daf2',
#          'datavalue': {'value': '158', 'type': 'string'},
#          'datatype': 'external-id'},
#         'type': 'statement',
#         'id': 'Q223880$2DC563F5-83A4-4D49-A788-6DB2243E9636',
#         'rank': 'normal'}],
#       'P436': [{'mainsnak': {'snaktype': 'value',
#          'property': 'P436',
#          'hash': '0e4bdbda6cfb1a7300f05f1c02e19f8b96354b10',
#          'datavalue': {'value': '6e2e9bc9-b267-4625-b03b-dc0200da8597',
#           'type': 'string'},
#          'datatype': 'external-id'},
#         'type': 'statement',
#         'id': 'Q223880$18EA0ADC-C438-4278-9A9B-3340086C5B4D',
#         'rank': 'normal',
#         'references': [{'hash': '706208b3024200fd0a39ad499808dd0d98d74065',
#           'snaks': {'P248': [{'snaktype': 'value',
#              'property': 'P248',
#              'hash': '623cc8f0e2f65afe4d66b91962d354a2f3aa9a27',
#              'datavalue': {'value': {'entity-type': 'item',
#                'numeric-id': 14005,
#                'id': 'Q14005'},
#               'type': 'wikibase-entityid'},
#              'datatype': 'wikibase-item'}]},
#           'snaks-order': ['P248']}]}],
#       'P495': [{'mainsnak': {'snaktype': 'value',
#          'property': 'P495',
#          'hash': '7fff5adac725cc34fb5c6dcfe502e2a7bbd045b2',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 145,
#            'id': 'Q145'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'},
#         'type': 'statement',
#         'id': 'Q223880$C4B471DB-7C2F-404D-84D8-26DF54F7C003',
#         'rank': 'normal',
#         'references': [{'hash': 'fa278ebfc458360e5aed63d5058cca83c46134f1',
#           'snaks': {'P143': [{'snaktype': 'value',
#              'property': 'P143',
#              'hash': 'e4f6d9441d0600513c4533c672b5ab472dc73694',
#              'datavalue': {'value': {'entity-type': 'item',
#                'numeric-id': 328,
#                'id': 'Q328'},
#               'type': 'wikibase-entityid'},
#              'datatype': 'wikibase-item'}]},
#           'snaks-order': ['P143']}]}],
#       'P3959': [{'mainsnak': {'snaktype': 'value',
#          'property': 'P3959',
#          'hash': 'ff5814e66b87e1b5d0835684cf32120293dff36d',
#          'datavalue': {'value': '001252838', 'type': 'string'},
#          'datatype': 'external-id'},
#         'type': 'statement',
#         'id': 'Q223880$d32613d4-4fb4-6c6b-d331-e3b8575fee31',
#         'rank': 'normal'},
#        {'mainsnak': {'snaktype': 'value',
#          'property': 'P3959',
#          'hash': '0d4c42caaeec40572c47dd268487fc995ae76079',
#          'datavalue': {'value': '003452001', 'type': 'string'},
#          'datatype': 'external-id'},
#         'type': 'statement',
#         'id': 'Q223880$5893eb2f-4aff-c32d-34e3-d19da0c61351',
#         'rank': 'normal'},
#        {'mainsnak': {'snaktype': 'value',
#          'property': 'P3959',
#          'hash': 'f56b1eecb2b75e7375711ed313910bd14f91a0e1',
#          'datavalue': {'value': '003864018', 'type': 'string'},
#          'datatype': 'external-id'},
#         'type': 'statement',
#         'id': 'Q223880$dbd7b3d8-424f-d754-6a00-2987934a4f54',
#         'rank': 'normal'}],
#       'P1417': [{'mainsnak': {'snaktype': 'value',
#          'property': 'P1417',
#          'hash': 'da76d5d6307cbbd9e9d96b2c995d50d462766681',
#          'datavalue': {'value': 'topic/Emma-novel-by-Austen',
#           'type': 'string'},
#          'datatype': 'external-id'},
#         'type': 'statement',
#         'qualifiers': {'P1810': [{'snaktype': 'value',
#            'property': 'P1810',
#            'hash': '983e105ebd1d228fd2ccab12793092db706f7860',
#            'datavalue': {'value': 'Emma', 'type': 'string'},
#            'datatype': 'string'}],
#          'P2093': [{'snaktype': 'value',
#            'property': 'P2093',
#            'hash': 'abb79c82dc26378c862e2a810094f03de220cbce',
#            'datavalue': {'value': 'Haley Bracken', 'type': 'string'},
#            'datatype': 'string'}]},
#         'qualifiers-order': ['P1810', 'P2093'],
#         'id': 'Q223880$DBD343AA-B21C-4553-9ACE-29A9E6640469',
#         'rank': 'normal'}],
#       'P407': [{'mainsnak': {'snaktype': 'value',
#          'property': 'P407',
#          'hash': 'daf1c4fcb58181b02dff9cc89deb084004ddae4b',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 1860,
#            'id': 'Q1860'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'},
#         'type': 'statement',
#         'id': 'Q223880$D6FF2F76-C83D-4331-A4F2-8904D7D827FF',
#         'rank': 'normal',
#         'references': [{'hash': 'd4bd87b862b12d99d26e86472d44f26858dee639',
#           'snaks': {'P143': [{'snaktype': 'value',
#              'property': 'P143',
#              'hash': 'f30cbd35620c4ea6d0633aaf0210a8916130469b',
#              'datavalue': {'value': {'entity-type': 'item',
#                'numeric-id': 8447,
#                'id': 'Q8447'},
#               'type': 'wikibase-entityid'},
#              'datatype': 'wikibase-item'}]},
#           'snaks-order': ['P143']}]}],
#       'P1889': [{'mainsnak': {'snaktype': 'value',
#          'property': 'P1889',
#          'hash': '7644de61139fd7b6d76c01397fa8a9a1d7839255',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 226248,
#            'id': 'Q226248'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'},
#         'type': 'statement',
#         'id': 'Q223880$B89E42A2-94BF-461D-B62C-BC19ABD418E8',
#         'rank': 'normal'}],
#       'P1922': [{'mainsnak': {'snaktype': 'value',
#          'property': 'P1922',
#          'hash': 'a708f69fd4a99a6d39caec7c3dc7427385f12d01',
#          'datavalue': {'value': {'text': 'Emma Woodhouse, handsome, clever, and rich, with a comfortable home and happy disposition, seemed to unite some of the best blessings of existence; and had lived nearly twenty-one years in the world with very little to distress or vex her.',
#            'language': 'en'},
#           'type': 'monolingualtext'},
#          'datatype': 'monolingualtext'},
#         'type': 'statement',
#         'id': 'Q223880$d454b558-43f6-c840-4fc0-9bd44013580d',
#         'rank': 'normal'}],
#       'P3132': [{'mainsnak': {'snaktype': 'value',
#          'property': 'P3132',
#          'hash': '59377f14fcbf15665624cf55106a89b5efbc611f',
#          'datavalue': {'value': {'text': 'But, in spite of these deficiencies, the wishes, the hopes, the confidence, the predictions of the small band of true friends who witnessed the ceremony, were fully answered in the perfect happiness of the union.',
#            'language': 'en'},
#           'type': 'monolingualtext'},
#          'datatype': 'monolingualtext'},
#         'type': 'statement',
#         'id': 'Q223880$0fc91391-4f16-2eea-3ce3-a343d16325a3',
#         'rank': 'normal'}],
#       'P1476': [{'mainsnak': {'snaktype': 'value',
#          'property': 'P1476',
#          'hash': '96af5536157c785fd90b94f7f528c627153e7de4',
#          'datavalue': {'value': {'text': 'Emma', 'language': 'en'},
#           'type': 'monolingualtext'},
#          'datatype': 'monolingualtext'},
#         'type': 'statement',
#         'qualifiers': {'P898': [{'snaktype': 'value',
#            'property': 'P898',
#            'hash': 'd7974aaa227a6e4f7d593e3ef965f177d129ccdb',
#            'datavalue': {'value': 'u02c8u025bmu0259', 'type': 'string'},
#            'datatype': 'string'}]},
#         'qualifiers-order': ['P898'],
#         'id': 'Q223880$06E65932-86E4-490A-894D-00F9CEA85308',
#         'rank': 'normal'}],
#       'P244': [{'mainsnak': {'snaktype': 'value',
#          'property': 'P244',
#          'hash': '80bcb811bbdec854b0ff79d8cf5b0e4231d23dbd',
#          'datavalue': {'value': 'no2005107571', 'type': 'string'},
#          'datatype': 'external-id'},
#         'type': 'statement',
#         'id': 'Q223880$7f2787df-434e-6a56-139b-6a5df313fd79',
#         'rank': 'normal'}],
#       'P4969': [{'mainsnak': {'snaktype': 'value',
#          'property': 'P4969',
#          'hash': '52fddd3ba61d12f2a798a447b562b4d07b9ae4c2',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 1338008,
#            'id': 'Q1338008'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'},
#         'type': 'statement',
#         'id': 'Q223880$999AD4B1-B83E-489C-82D4-8BCCC978CB57',
#         'rank': 'normal',
#         'references': [{'hash': '451ad9d7f625939ad64e710c640d3eb7aef5fa19',
#           'snaks': {'P3452': [{'snaktype': 'value',
#              'property': 'P3452',
#              'hash': 'f349c73938d977c8ea741d9918a16102a4e66792',
#              'datavalue': {'value': {'entity-type': 'item',
#                'numeric-id': 1338008,
#                'id': 'Q1338008'},
#               'type': 'wikibase-entityid'},
#              'datatype': 'wikibase-item'}]},
#           'snaks-order': ['P3452']}]},
#        {'mainsnak': {'snaktype': 'value',
#          'property': 'P4969',
#          'hash': '6f3ed87ff713c737dc33cae57a073485af7fa790',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 2089221,
#            'id': 'Q2089221'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'},
#         'type': 'statement',
#         'id': 'Q223880$72AD5927-31B2-4A2C-BFEC-90D049D7545E',
#         'rank': 'normal',
#         'references': [{'hash': '91b651d6f8513d724e0647e0eb395b4cecedd791',
#           'snaks': {'P3452': [{'snaktype': 'value',
#              'property': 'P3452',
#              'hash': 'eefd5e2d60d678be861f58e70dbefe9eeef979d2',
#              'datavalue': {'value': {'entity-type': 'item',
#                'numeric-id': 2089221,
#                'id': 'Q2089221'},
#               'type': 'wikibase-entityid'},
#              'datatype': 'wikibase-item'}]},
#           'snaks-order': ['P3452']}]},
#        {'mainsnak': {'snaktype': 'value',
#          'property': 'P4969',
#          'hash': 'da7ce70914227c44faf04bde31b3610c6cb756c1',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 2565731,
#            'id': 'Q2565731'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'},
#         'type': 'statement',
#         'id': 'Q223880$B13C975F-4B66-4412-BBEC-58F2523487B9',
#         'rank': 'normal',
#         'references': [{'hash': 'c466c124542375cfd332e2a882bfbd6ae2429532',
#           'snaks': {'P3452': [{'snaktype': 'value',
#              'property': 'P3452',
#              'hash': '46b08693905b13e84e7ba1058f41070a15c66f87',
#              'datavalue': {'value': {'entity-type': 'item',
#                'numeric-id': 2565731,
#                'id': 'Q2565731'},
#               'type': 'wikibase-entityid'},
#              'datatype': 'wikibase-item'}]},
#           'snaks-order': ['P3452']}]},
#        {'mainsnak': {'snaktype': 'value',
#          'property': 'P4969',
#          'hash': 'c5404f3fafe14e256fa0ff51d06ed1dbbf89152e',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 65091224,
#            'id': 'Q65091224'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'},
#         'type': 'statement',
#         'id': 'Q223880$6b6baad7-48e4-aaa9-0409-f4d512b96534',
#         'rank': 'normal'},
#        {'mainsnak': {'snaktype': 'value',
#          'property': 'P4969',
#          'hash': 'd83ea3986d8a2e876b7db0754cc9c36a2145ab27',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 4531677,
#            'id': 'Q4531677'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'},
#         'type': 'statement',
#         'id': 'Q223880$56b11484-4e0c-59dc-9333-135a2aacf3d0',
#         'rank': 'normal'},
#        {'mainsnak': {'snaktype': 'value',
#          'property': 'P4969',
#          'hash': '7a59e01707c21c5b94335e60b0853223e49db8ea',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 388601,
#            'id': 'Q388601'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'},
#         'type': 'statement',
#         'id': 'Q223880$be4ab2f3-4d8e-22e0-f6fc-5ec6a8685536',
#         'rank': 'normal'},
#        {'mainsnak': {'snaktype': 'value',
#          'property': 'P4969',
#          'hash': '5ab5c7624849f5761550086cf4b8022edc3206b9',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 1337993,
#            'id': 'Q1337993'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'},
#         'type': 'statement',
#         'id': 'Q223880$57bfc730-454d-f58a-83c6-53bfffdc62eb',
#         'rank': 'normal'},
#        {'mainsnak': {'snaktype': 'value',
#          'property': 'P4969',
#          'hash': 'd0d1991762c0d7d179f0a68beca9698d808ec4c2',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 4531678,
#            'id': 'Q4531678'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'},
#         'type': 'statement',
#         'id': 'Q223880$4723174b-4678-4c65-764d-41cf7f61c0bf',
#         'rank': 'normal'},
#        {'mainsnak': {'snaktype': 'value',
#          'property': 'P4969',
#          'hash': 'b957b9406befefb9b8d7a7059a3e6b6965c1132c',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 931165,
#            'id': 'Q931165'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'},
#         'type': 'statement',
#         'id': 'Q223880$f7f7248a-41ab-0f4f-7a66-94ab1dfd9d79',
#         'rank': 'normal'}],
#       'P6216': [{'mainsnak': {'snaktype': 'value',
#          'property': 'P6216',
#          'hash': 'f69dc45ce9c48664155022498b34100d801bd549',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 19652,
#            'id': 'Q19652'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'},
#         'type': 'statement',
#         'qualifiers': {'P1001': [{'snaktype': 'value',
#            'property': 'P1001',
#            'hash': '91dce20cb7cf8d03dc976a70e56b19939881d751',
#            'datavalue': {'value': {'entity-type': 'item',
#              'numeric-id': 60332278,
#              'id': 'Q60332278'},
#             'type': 'wikibase-entityid'},
#            'datatype': 'wikibase-item'}],
#          'P459': [{'snaktype': 'value',
#            'property': 'P459',
#            'hash': '8f1a08d7359ea45500b600d7ad0f13a7f032145e',
#            'datavalue': {'value': {'entity-type': 'item',
#              'numeric-id': 29940705,
#              'id': 'Q29940705'},
#             'type': 'wikibase-entityid'},
#            'datatype': 'wikibase-item'}]},
#         'qualifiers-order': ['P1001', 'P459'],
#         'id': 'Q223880$865318B2-5CD2-4DA6-BCDA-820BA9283C43',
#         'rank': 'normal'},
#        {'mainsnak': {'snaktype': 'value',
#          'property': 'P6216',
#          'hash': 'f69dc45ce9c48664155022498b34100d801bd549',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 19652,
#            'id': 'Q19652'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'},
#         'type': 'statement',
#         'qualifiers': {'P1001': [{'snaktype': 'value',
#            'property': 'P1001',
#            'hash': 'fd03a46bac885aad8c96834e86183c078494dce6',
#            'datavalue': {'value': {'entity-type': 'item',
#              'numeric-id': 30,
#              'id': 'Q30'},
#             'type': 'wikibase-entityid'},
#            'datatype': 'wikibase-item'}],
#          'P459': [{'snaktype': 'value',
#            'property': 'P459',
#            'hash': 'e8a997f8c7723e2bc8daa542a8b44577d4b3b7eb',
#            'datavalue': {'value': {'entity-type': 'item',
#              'numeric-id': 47246828,
#              'id': 'Q47246828'},
#             'type': 'wikibase-entityid'},
#            'datatype': 'wikibase-item'}]},
#         'qualifiers-order': ['P1001', 'P459'],
#         'id': 'Q223880$D642BCDE-5A3E-4C71-AB13-9335E4D64A9D',
#         'rank': 'normal'}],
#       'P214': [{'mainsnak': {'snaktype': 'value',
#          'property': 'P214',
#          'hash': 'a4af1337c4c0d4f53a45c34e9e17da818280811f',
#          'datavalue': {'value': '178480306', 'type': 'string'},
#          'datatype': 'external-id'},
#         'type': 'statement',
#         'id': 'Q223880$C7FE537C-6848-4D51-94E7-11E77F4766BE',
#         'rank': 'normal'}],
#       'P1085': [{'mainsnak': {'snaktype': 'value',
#          'property': 'P1085',
#          'hash': '77e2db2468bdce852855ade240fcce01f794c55e',
#          'datavalue': {'value': '364', 'type': 'string'},
#          'datatype': 'external-id'},
#         'type': 'statement',
#         'id': 'Q223880$ef522c87-42fc-19f1-28a3-64da24b86031',
#         'rank': 'normal'}],
#       'P648': [{'mainsnak': {'snaktype': 'value',
#          'property': 'P648',
#          'hash': 'ba49a722313cb4c055c97ffa2fa7e931117c98d1',
#          'datavalue': {'value': 'OL66513W', 'type': 'string'},
#          'datatype': 'external-id'},
#         'type': 'statement',
#         'id': 'Q223880$d76d7b40-4a60-cdef-fec2-9735b19a831d',
#         'rank': 'normal'}],
#       'P1617': [{'mainsnak': {'snaktype': 'value',
#          'property': 'P1617',
#          'hash': 'b0a78a4e45ebfe6d9015c7490f6a78457b108dcd',
#          'datavalue': {'value': 'e6c49a74-eb85-4bbe-bd32-d71fd942e1a0',
#           'type': 'string'},
#          'datatype': 'external-id'},
#         'type': 'statement',
#         'id': 'Q223880$01ef7eba-414f-4ab2-a670-307ca611cc74',
#         'rank': 'normal',
#         'references': [{'hash': '8582d8416671f1f2567247201bac753552435ca5',
#           'snaks': {'P248': [{'snaktype': 'value',
#              'property': 'P248',
#              'hash': 'ea55dc6ac5c3ab77c77d4ae7979e3276d0d4cd20',
#              'datavalue': {'value': {'entity-type': 'item',
#                'numeric-id': 18336371,
#                'id': 'Q18336371'},
#               'type': 'wikibase-entityid'},
#              'datatype': 'wikibase-item'}]},
#           'snaks-order': ['P248']}]}],
#       'P6839': [{'mainsnak': {'snaktype': 'value',
#          'property': 'P6839',
#          'hash': 'fae4742e6b2b6bc56cbecbc8f97091d295d85418',
#          'datavalue': {'value': 'Literature/Emma', 'type': 'string'},
#          'datatype': 'external-id'},
#         'type': 'statement',
#         'id': 'Q223880$d3bcaaed-476c-7ba7-89c8-2ae4d376f6bd',
#         'rank': 'normal'}],
#       'P2438': [{'mainsnak': {'snaktype': 'value',
#          'property': 'P2438',
#          'hash': 'fc596d0ce27ea1247e3464dca29545fa1554c7ae',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 63532437,
#            'id': 'Q63532437'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'},
#         'type': 'statement',
#         'id': 'Q223880$4fe05751-47d8-ec55-a126-cd95c63375d4',
#         'rank': 'normal'}],
#       'P7937': [{'mainsnak': {'snaktype': 'value',
#          'property': 'P7937',
#          'hash': '1f3796a438db67e51d8cac2bad920878e37e51c9',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 8261,
#            'id': 'Q8261'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'},
#         'type': 'statement',
#         'id': 'Q223880$b2ce48db-480a-5374-e4fa-0a623490f932',
#         'rank': 'normal'}],
#       'P1149': [{'mainsnak': {'snaktype': 'value',
#          'property': 'P1149',
#          'hash': 'ddf8d9b383a573ad5681d14351f14bfb2afe8069',
#          'datavalue': {'value': 'PR4034.E5', 'type': 'string'},
#          'datatype': 'external-id'},
#         'type': 'statement',
#         'id': 'Q223880$9b204717-4615-e945-5aee-0eef010b06f4',
#         'rank': 'normal'}],
#       'P8189': [{'mainsnak': {'snaktype': 'value',
#          'property': 'P8189',
#          'hash': '0ec15e1eeb6965e2f894b5ae9ef882c8e96e6b3f',
#          'datavalue': {'value': '987007583568805171', 'type': 'string'},
#          'datatype': 'external-id'},
#         'type': 'statement',
#         'id': 'Q223880$5A70F468-76BB-4AA4-9ECD-5080D905B553',
#         'rank': 'normal'}],
#       'P8419': [{'mainsnak': {'snaktype': 'value',
#          'property': 'P8419',
#          'hash': '7a494d5a38aa645207fe7c7d6bddf66818dfab37',
#          'datavalue': {'value': 'Emma - Jane Austen', 'type': 'string'},
#          'datatype': 'external-id'},
#         'type': 'statement',
#         'qualifiers': {'P1552': [{'snaktype': 'value',
#            'property': 'P1552',
#            'hash': '2676d76a32e544ce99d8cfe832a8ec77039a8f2e',
#            'datavalue': {'value': {'entity-type': 'item',
#              'numeric-id': 105265074,
#              'id': 'Q105265074'},
#             'type': 'wikibase-entityid'},
#            'datatype': 'wikibase-item'}],
#          'P3831': [{'snaktype': 'value',
#            'property': 'P3831',
#            'hash': '8d253d0aa2a99569829d70d981b9a9cdc92881ab',
#            'datavalue': {'value': {'entity-type': 'item',
#              'numeric-id': 110914098,
#              'id': 'Q110914098'},
#             'type': 'wikibase-entityid'},
#            'datatype': 'wikibase-item'}]},
#         'qualifiers-order': ['P1552', 'P3831'],
#         'id': 'Q223880$FA397672-1AEF-449B-8BF3-9F06AE37ECB4',
#         'rank': 'normal'}],
#       'P180': [{'mainsnak': {'snaktype': 'value',
#          'property': 'P180',
#          'hash': 'e03a4901c5fe82ab778c1ffb83df9ed527dc66f8',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 36322,
#            'id': 'Q36322'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'},
#         'type': 'statement',
#         'id': 'Q223880$0A955EFE-EC11-4BD7-ADD5-71C66815CFA7',
#         'rank': 'normal',
#         'references': [{'hash': 'cf7e87ff0ab4e3218527b5ce611c4f0949d6744e',
#           'snaks': {'P648': [{'snaktype': 'value',
#              'property': 'P648',
#              'hash': 'ba49a722313cb4c055c97ffa2fa7e931117c98d1',
#              'datavalue': {'value': 'OL66513W', 'type': 'string'},
#              'datatype': 'external-id'}]},
#           'snaks-order': ['P648']}]}],
#       'P10688': [{'mainsnak': {'snaktype': 'value',
#          'property': 'P10688',
#          'hash': 'c3ec59e7ea27b33dcb98d10bcef9c8b8b2d4a6f6',
#          'datavalue': {'value': '597', 'type': 'string'},
#          'datatype': 'external-id'},
#         'type': 'statement',
#         'id': 'Q223880$75D9CA2F-ED83-49AE-9C6D-29DE4A899A12',
#         'rank': 'normal',
#         'references': [{'hash': '75bcf949695e9d1102f80a1e1b75966cf992f592',
#           'snaks': {'P854': [{'snaktype': 'value',
#              'property': 'P854',
#              'hash': '6830d477e5e8247f99c84b27289a90834b1a2e3c',
#              'datavalue': {'value': 'https://www.personality-database.com/profile?pid=2&cid=3&sub_cat_id=597',
#               'type': 'string'},
#              'datatype': 'url'}],
#            'P1476': [{'snaktype': 'value',
#              'property': 'P1476',
#              'hash': 'b1f864ced36ab56992d679464eac49b7d380bf8a',
#              'datavalue': {'value': {'text': 'Emma (Novel) MBTI Personality Type - Literature',
#                'language': 'en'},
#               'type': 'monolingualtext'},
#              'datatype': 'monolingualtext'}],
#            'P813': [{'snaktype': 'value',
#              'property': 'P813',
#              'hash': 'e85b98c7884c8659c02fd6c55bbea5f16e6dcc93',
#              'datavalue': {'value': {'time': '+2022-07-26T00:00:00Z',
#                'timezone': 0,
#                'before': 0,
#                'after': 0,
#                'precision': 11,
#                'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#               'type': 'time'},
#              'datatype': 'time'}]},
#           'snaks-order': ['P854', 'P1476', 'P813']}]}],
#       'P269': [{'mainsnak': {'snaktype': 'value',
#          'property': 'P269',
#          'hash': 'fe4214057079bde1f1c797e93b0bb969065d4a19',
#          'datavalue': {'value': '02737582X', 'type': 'string'},
#          'datatype': 'external-id'},
#         'type': 'statement',
#         'id': 'Q223880$F8CC656F-BC79-49BE-A0B9-D32736F90166',
#         'rank': 'normal'}],
#       'P11686': [{'mainsnak': {'snaktype': 'value',
#          'property': 'P11686',
#          'hash': '0c303d5df41b8100c4eb169441dfbafb96ed9eb9',
#          'datavalue': {'value': '981059289042406706', 'type': 'string'},
#          'datatype': 'external-id'},
#         'type': 'statement',
#         'id': 'Q223880$309BED55-2CEE-4681-9EE4-8BF7C9FCF755',
#         'rank': 'normal',
#         'references': [{'hash': 'e2c5edf6f884ca82abb815d026c5aaba713feaaa',
#           'snaks': {'P214': [{'snaktype': 'value',
#              'property': 'P214',
#              'hash': 'a4af1337c4c0d4f53a45c34e9e17da818280811f',
#              'datavalue': {'value': '178480306', 'type': 'string'},
#              'datatype': 'external-id'}]},
#           'snaks-order': ['P214']}]}],
#       'P9984': [{'mainsnak': {'snaktype': 'value',
#          'property': 'P9984',
#          'hash': '2a3085c8bf0032ed95832892af22af7d65dea97a',
#          'datavalue': {'value': '981059289042406706', 'type': 'string'},
#          'datatype': 'external-id'},
#         'type': 'statement',
#         'id': 'Q223880$A1B44268-C039-49B7-A2A9-2C74455E7AD7',
#         'rank': 'normal',
#         'references': [{'hash': 'e2c5edf6f884ca82abb815d026c5aaba713feaaa',
#           'snaks': {'P214': [{'snaktype': 'value',
#              'property': 'P214',
#              'hash': 'a4af1337c4c0d4f53a45c34e9e17da818280811f',
#              'datavalue': {'value': '178480306', 'type': 'string'},
#              'datatype': 'external-id'}]},
#           'snaks-order': ['P214']}]}],
#       'P11932': [{'mainsnak': {'snaktype': 'value',
#          'property': 'P11932',
#          'hash': 'f3f242abfbce1631b7c4db4d6a9ea5f22bcdffcc',
#          'datavalue': {'value': '5384', 'type': 'string'},
#          'datatype': 'external-id'},
#         'type': 'statement',
#         'id': 'Q223880$5c3b38b0-48dc-b238-bdc6-f8bc82d66a44',
#         'rank': 'normal'}],
#       'P953': [{'mainsnak': {'snaktype': 'value',
#          'property': 'P953',
#          'hash': 'a0973719bab82389885aab89fadf0ca4d01adfbf',
#          'datavalue': {'value': 'https://standardebooks.org/ebooks/jane-austen/emma',
#           'type': 'string'},
#          'datatype': 'url'},
#         'type': 'statement',
#         'id': 'Q223880$08da0b52-4194-0343-938f-0dd22c4f4ff8',
#         'rank': 'normal'}],
#       'P227': [{'mainsnak': {'snaktype': 'value',
#          'property': 'P227',
#          'hash': 'f866a5666ca87c548a190f5d62598344eca3855b',
#          'datavalue': {'value': '4277660-0', 'type': 'string'},
#          'datatype': 'external-id'},
#         'type': 'statement',
#         'id': 'Q223880$a43b53dc-4b36-7423-a244-19f79344fd46',
#         'rank': 'normal'}],
#       'P12931': [{'mainsnak': {'snaktype': 'value',
#          'property': 'P12931',
#          'hash': 'ecb230a3ca3c87acdbe3c033a44aa2e6987f2e04',
#          'datavalue': {'value': '1469', 'type': 'string'},
#          'datatype': 'external-id'},
#         'type': 'statement',
#         'id': 'Q223880$A25083D9-1090-456C-AB99-586A1AAB281C',
#         'rank': 'normal',
#         'references': [{'hash': '7030e51880292aacda0d1fac47aef902e61615c7',
#           'snaks': {'P248': [{'snaktype': 'value',
#              'property': 'P248',
#              'hash': 'cfd6260c3621f3fdb39013c3ecc6ac87635b3b07',
#              'datavalue': {'value': {'entity-type': 'item',
#                'numeric-id': 76504070,
#                'id': 'Q76504070'},
#               'type': 'wikibase-entityid'},
#              'datatype': 'wikibase-item'}],
#            'P813': [{'snaktype': 'value',
#              'property': 'P813',
#              'hash': 'ef7e186b9c210c90d9beb8488830da37e26a38eb',
#              'datavalue': {'value': {'time': '+2024-08-23T00:00:00Z',
#                'timezone': 0,
#                'before': 0,
#                'after': 0,
#                'precision': 11,
#                'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#               'type': 'time'},
#              'datatype': 'time'}]},
#           'snaks-order': ['P248', 'P813']}]}],
#       'P5940': [{'mainsnak': {'snaktype': 'value',
#          'property': 'P5940',
#          'hash': 'f8e441a3e3354436a3d567eb90c02ddad79a21ff',
#          'datavalue': {'value': {'entity-type': 'item',
#            'numeric-id': 18752812,
#            'id': 'Q18752812'},
#           'type': 'wikibase-entityid'},
#          'datatype': 'wikibase-item'},
#         'type': 'statement',
#         'id': 'Q223880$50532769-4228-efca-a8d4-7e25ff0abac4',
#         'rank': 'normal'}],
#       'P304': [{'mainsnak': {'snaktype': 'value',
#          'property': 'P304',
#          'hash': '0b68f55b4d5f023b8f9f9ededdf412963b6cbacd',
#          'datavalue': {'value': '1036', 'type': 'string'},
#          'datatype': 'string'},
#         'type': 'statement',
#         'id': 'Q223880$C6CD7E84-7D6E-4E4B-AD33-17F3E737F237',
#         'rank': 'normal'}],
#       'P478': [{'mainsnak': {'snaktype': 'value',
#          'property': 'P478',
#          'hash': '0cb10c03d7ed6b77297421fc9b82339df1350d48',
#          'datavalue': {'value': '3', 'type': 'string'},
#          'datatype': 'string'},
#         'type': 'statement',
#         'id': 'Q223880$51A57F8A-4A7E-45B8-AB2E-94CA232D57A7',
#         'rank': 'normal'}]},
#      'sitelinks': {'afwiki': {'site': 'afwiki',
#        'title': 'Emma (Austen-roman)',
#        'badges': []},
#       'arwiki': {'site': 'arwiki',
#        'title': 'u0625u064au0645u0627',
#        'badges': []},
#       'bewiki': {'site': 'bewiki',
#        'title': 'u042du043cu0430 (u0440u0430u043cu0430u043d)',
#        'badges': []},
#       'bgwiki': {'site': 'bgwiki', 'title': 'u0415u043cu0430', 'badges': []},
#       'cawiki': {'site': 'cawiki',
#        'title': 'Emma (novelu00b7la)',
#        'badges': []},
#       'cawikiquote': {'site': 'cawikiquote', 'title': 'Emma', 'badges': []},
#       'cswiki': {'site': 'cswiki', 'title': 'Emma (romu00e1n)', 'badges': []},
#       'cywiki': {'site': 'cywiki', 'title': 'Emma', 'badges': []},
#       'dawiki': {'site': 'dawiki', 'title': 'Emma (roman)', 'badges': []},
#       'dewiki': {'site': 'dewiki', 'title': 'Emma (Roman)', 'badges': []},
#       'elwiki': {'site': 'elwiki',
#        'title': 'u0388u03bcu03bcu03b1',
#        'badges': []},
#       'enwiki': {'site': 'enwiki', 'title': 'Emma (novel)', 'badges': []},
#       'enwikiquote': {'site': 'enwikiquote',
#        'title': 'Emma (novel)',
#        'badges': []},
#       'eowiki': {'site': 'eowiki', 'title': 'Emma (romano)', 'badges': []},
#       'eswiki': {'site': 'eswiki', 'title': 'Emma', 'badges': []},
#       'etwikiquote': {'site': 'etwikiquote', 'title': 'Emma', 'badges': []},
#       'fawiki': {'site': 'fawiki',
#        'title': 'u0627u0645u0627 (u0631u0645u0627u0646)',
#        'badges': []},
#       'fiwiki': {'site': 'fiwiki', 'title': 'Emma (romaani)', 'badges': []},
#       'frwiki': {'site': 'frwiki',
#        'title': 'Emma (roman)',
#        'badges': ['Q17437796']},
#       'frwikiquote': {'site': 'frwikiquote', 'title': 'Emma', 'badges': []},
#       'hewiki': {'site': 'hewiki',
#        'title': 'u05d0u05deu05d4 (u05e1u05e4u05e8)',
#        'badges': []},
#       'hiwiki': {'site': 'hiwiki', 'title': 'u090fu092eu093e', 'badges': []},
#       'huwiki': {'site': 'huwiki',
#        'title': 'Emma (Jane Austen-regu00e9ny)',
#        'badges': []},
#       'hywiki': {'site': 'hywiki',
#        'title': 'u0537u0574u0574u0561 (u057eu0565u057a)',
#        'badges': []},
#       'idwiki': {'site': 'idwiki', 'title': 'Emma', 'badges': []},
#       'itwiki': {'site': 'itwiki', 'title': 'Emma (romanzo)', 'badges': []},
#       'jawiki': {'site': 'jawiki',
#        'title': 'u30a8u30de (u5c0fu8aac)',
#        'badges': []},
#       'kawiki': {'site': 'kawiki', 'title': 'u10d4u10dbu10d0', 'badges': []},
#       'kowiki': {'site': 'kowiki',
#        'title': 'uc5e0ub9c8 (uc18cuc124)',
#        'badges': []},
#       'kywiki': {'site': 'kywiki',
#        'title': 'u042du043cu043cu0430',
#        'badges': []},
#       'nlwiki': {'site': 'nlwiki', 'title': 'Emma (roman)', 'badges': []},
#       'nowiki': {'site': 'nowiki', 'title': 'Emma (roman)', 'badges': []},
#       'plwiki': {'site': 'plwiki',
#        'title': 'Emma (powieu015bu0107)',
#        'badges': []},
#       'plwikiquote': {'site': 'plwikiquote', 'title': 'Emma', 'badges': []},
#       'ptwiki': {'site': 'ptwiki', 'title': 'Emma', 'badges': []},
#       'rowiki': {'site': 'rowiki', 'title': 'Emma (roman)', 'badges': []},
#       'ruwiki': {'site': 'ruwiki',
#        'title': 'u042du043cu043cu0430 (u0440u043eu043cu0430u043d)',
#        'badges': []},
#       'ruwikiquote': {'site': 'ruwikiquote',
#        'title': 'u042du043cu043cu0430 (u0440u043eu043cu0430u043d)',
#        'badges': []},
#       'simplewiki': {'site': 'simplewiki',
#        'title': 'Emma (novel)',
#        'badges': []},
#       'slwiki': {'site': 'slwiki', 'title': 'Emma', 'badges': []},
#       'svwiki': {'site': 'svwiki', 'title': 'Emma (roman)', 'badges': []},
#       'trwiki': {'site': 'trwiki', 'title': 'Emma (roman)', 'badges': []},
#       'ukwiki': {'site': 'ukwiki',
#        'title': 'u0415u043cu043cu0430 (u0440u043eu043cu0430u043d)',
#        'badges': []},
#       'uzwiki': {'site': 'uzwiki', 'title': 'Emma (roman)', 'badges': []},
#       'viwiki': {'site': 'viwiki',
#        'title': 'Emma (tiu1ec3u thuyu1ebft)',
#        'badges': []},
#       'zhwiki': {'site': 'zhwiki',
#        'title': 'u611bu746a (u5c0fu8aaa)',
#        'badges': []}}}},
#    'success': 1},
#   'wikidata_last_update': 'Wed, 15 Jan 25 19:42:40 +0000',
#   'url': '',
#   'experience': [{'id': 83,
#     'name': 'Alienation',
#     'slug': 'alienation',
#     'description': 'Distrusting yourself. Alientation is the inverse of paranoia, which involves distrusting someone or something outside of yourself.\r\n\r\nAlso called: Distrust\r\n\r\n'}],
#   'propose_experience': False,
#   'define_proposed_experienced': '',
#   'Year_of_Experience': 2024,
#   'feature': '',
#   'technology': [{'id': 114,
#     'name': 'Almighty Heart + Soliloquy',
#     'slug': 'almighty-heart-plus-soliloquy',
#     'description': 'The combination of the secret discloser (a narrative technology in which a narrator shares an intimate secret about a character) with wish fulfillment (a plot technology that shows a character getting everything they want) and soliloquy (a character who reveals a conflict that you have experienced, prompting identification)\r\n'}],
#   'propose_technology': False,
#   'define_proposed_technology': '',
#   'benefit_of_experience': 179,
#   'propose_benefit': False,
#   'theorize_benefit': '',
#   'benefit': [{'id': 179,
#     'name': 'Bias Reduction',
#     'slug': 'bias-reduction',
#     'description': ''}]},
#  '_links': {'self': [{'href': 'https://env-1120817.us.reclaim.cloud/wp-json/wp/v2/user-experience/474'}],
#   'collection': [{'href': 'https://env-1120817.us.reclaim.cloud/wp-json/wp/v2/user-experience'}],
#   'about': [{'href': 'https://env-1120817.us.reclaim.cloud/wp-json/wp/v2/types/user-experience'}],
#   'author': [{'embeddable': True,
#     'href': 'https://env-1120817.us.reclaim.cloud/wp-json/wp/v2/users/4'}],
#   'acf:term': [{'embeddable': True,
#     'taxonomy': 'benefit',
#     'href': 'https://env-1120817.us.reclaim.cloud/wp-json/wp/v2/benefit/179'},
#    {'embeddable': True,
#     'taxonomy': 'technology',
#     'href': 'https://env-1120817.us.reclaim.cloud/wp-json/wp/v2/technology/114'},
#    {'embeddable': True,
#     'taxonomy': 'experience',
#     'href': 'https://env-1120817.us.reclaim.cloud/wp-json/wp/v2/experience/83'}],
#   'wp:featuredmedia': [{'embeddable': True,
#     'href': 'https://env-1120817.us.reclaim.cloud/wp-json/wp/v2/media/458'}],
#   'wp:attachment': [{'href': 'https://env-1120817.us.reclaim.cloud/wp-json/wp/v2/media?parent=474'}],
#   'wp:term': [{'taxonomy': 'benefit',
#     'embeddable': True,
#     'href': 'https://env-1120817.us.reclaim.cloud/wp-json/wp/v2/benefit?post=474'},
#    {'taxonomy': 'experience',
#     'embeddable': True,
#     'href': 'https://env-1120817.us.reclaim.cloud/wp-json/wp/v2/experience?post=474'},
#    {'taxonomy': 'technology',
#     'embeddable': True,
#     'href': 'https://env-1120817.us.reclaim.cloud/wp-json/wp/v2/technology?post=474'},
#    {'taxonomy': 'user-proposed-benefit',
#     'embeddable': True,
#     'href': 'https://env-1120817.us.reclaim.cloud/wp-json/wp/v2/user-proposed-benefit?post=474'},
#    {'taxonomy': 'user-proposed-experience',
#     'embeddable': True,
#     'href': 'https://env-1120817.us.reclaim.cloud/wp-json/wp/v2/user-proposed-experience?post=474'},
#    {'taxonomy': 'user-proposed-technology',
#     'embeddable': True,
#     'href': 'https://env-1120817.us.reclaim.cloud/wp-json/wp/v2/user-proposed-technology?post=474'}],
#   'curies': [{'name': 'wp',
#     'href': 'https://api.w.org/{rel}',
#     'templated': True}]}}

# %% [markdown]
# ### Convert Request JSON to DataFrame
# Columsn to keep: source_narratives, benefit, experience,

# %%
for k,v in wp_data[0].items():
    print (k)
# Out:
# id
# count
# description
# link
# name
# slug
# taxonomy
# meta
# acf
# _links

# %%
# %%time

wp_data[3]['benefit'][0]['name']
# Out:
# CPU times: user 7 μs, sys: 1 μs, total: 8 μs
# Wall time: 11.7 μs
# 'Faith'

# %%
# %%time

def extract_values(dictionary):
    name = dictionary['name']
    # name = dictionary.get('name', None)
    return name

wp_test = pd.DataFrame(wp_data)
wp_test = wp_test[['id', 'author', 'date', 'benefit', 'experience', 'technology', 'acf']]
wp_test['dumb'] = pd.json_normalize(wp_test['benefit'])
wp_test['benefit'] = pd.json_normalize(wp_test['dumb'])['name']


# wp_test['benefit'] = pd.DataFrame.from_dict(wp_test)
# wp_test['benefit'] = wp_test['benefit'].apply(lambda x: pd.Series(extract_values(x)))

# for k,v in test['benefit'].items():
#     print (k)

# [n['name'] for n in test['benefit']]

# for r in test['benefit']:
#     print (r['name'])

# benefits = test['benefit']

# wp_test['new'] = pd.json_normalize(wp_test['benefit'])['name']
wp_test.head()
# Out:
# CPU times: user 13.6 ms, sys: 3.37 ms, total: 17 ms
# Wall time: 34.9 ms
#     id  author                 date         benefit  \
# 0  474       4  2025-01-15T19:26:15  Bias Reduction
# 1  362       5  2025-01-09T21:27:04           Faith
# 2  364       5  2025-01-09T20:56:26      Generosity
# 3  363       5  2025-01-09T20:55:14           Faith
# 4  361       5  2025-01-09T20:51:11   Peace of Mind
#
#                                           experience  \
# 0  [{'id': 83, 'name': 'Alienation', 'slug': 'ali...
# 1  [{'id': 29, 'name': 'Wonder', 'slug': 'wonder'...
# 2  [{'id': 29, 'name': 'Wonder', 'slug': 'wonder'...
# 3  [{'id': 29, 'name': 'Wonder', 'slug': 'wonder'...
# 4  [{'id': 111, 'name': 'Tranquility', 'slug': 't...
#
#                                           technology  \
# 0  [{'id': 114, 'name': 'Almighty Heart + Soliloq...
# 1  [{'id': 199, 'name': 'Enigma', 'slug': 'enigma...
# 2  [{'id': 170, 'name': 'Stretch', 'slug': 'stret...
# 3  [{'id': 150, 'name': 'Plot Twist', 'slug': 'pl...
# 4  [{'id': 169, 'name': 'Stream of Consciousness'...
#
#                                                  acf  \
# 0  {'title_of_creative_work': 'Test', 'in_wikidat...
# 1  {'title_of_creative_work': 'Mystery Plays', 'i...
# 2  {'title_of_creative_work': 'Oedipus', 'in_wiki...
# 3  {'title_of_creative_work': 'Oedipus', 'in_wiki...
# 4  {'title_of_creative_work': 'Me Before You', 'i...
#
#                                                 dumb
# 0  {'id': 179, 'name': 'Bias Reduction', 'slug': ...
# 1  {'id': 69, 'name': 'Faith', 'slug': 'faith', '...
# 2  {'id': 61, 'name': 'Generosity', 'slug': 'gene...
# 3  {'id': 69, 'name': 'Faith', 'slug': 'faith', '...
# 4  {'id': 192, 'name': 'Peace of Mind', 'slug': '...

# %%
# %%time

def extract_values(dictionary):
    name = dictionary['name']
    return name

def transform_to_dataframe(api_call):
    api_data = pd.DataFrame(api_call)
    api_data = api_data[['id', 'author', 'date', 'benefit', 'experience', 'technology', 'acf']] # Select columns to work with. Add 'wikidata' when ready.
    api_data['title'] = pd.json_normalize(api_data['acf'])['title_of_creative_work']
    api_data['QID'] = pd.json_normalize(api_data['acf'])['wikidata-qid']
    # This should be cleaner...
    api_data['bene_del'] = pd.json_normalize(api_data['benefit'])
    api_data['benefit'] = pd.json_normalize(api_data['bene_del'])['name']
    api_data['exp_del'] = pd.json_normalize(api_data['experience'])
    api_data['experience'] = pd.json_normalize(api_data['exp_del'])['name']
    api_data['tech_del'] = pd.json_normalize(api_data['technology'])
    api_data['technology'] = pd.json_normalize(api_data['tech_del'])['name']
    del api_data['acf'], api_data['bene_del'], api_data['exp_del'], api_data['tech_del']

    return api_data

data = transform_to_dataframe(wp_data)

data.head()
# Out:
# CPU times: user 6.4 s, sys: 437 ms, total: 6.84 s
# Wall time: 7.81 s
#     id  author                 date         benefit   experience  \
# 0  474       4  2025-01-15T19:26:15  Bias Reduction   Alienation
# 1  362       5  2025-01-09T21:27:04           Faith       Wonder
# 2  364       5  2025-01-09T20:56:26      Generosity       Wonder
# 3  363       5  2025-01-09T20:55:14           Faith       Wonder
# 4  361       5  2025-01-09T20:51:11   Peace of Mind  Tranquility
#
#                    technology          title        QID
# 0  Almighty Heart + Soliloquy           Test    Q223880
# 1                      Enigma  Mystery Plays    Q240911
# 2                     Stretch        Oedipus    Q148643
# 3                  Plot Twist        Oedipus    Q148643
# 4     Stream of Consciousness  Me Before You  Q20657314

# %% [markdown]
# ## Network

# %%
# %%time

# Create network graph from dataframe (df) and three columns (c1, c2, c3),
# where c1 is the source of c2; c2 is the source of c3.
def create_network_graph(df, c1, c2, c3):
    c1_c2 = df[[c1, c2]].rename(columns = {c1:'source', c2:'target'})
    c2_c3 = df[[c2, c3]].rename(columns = {c2:'source', c3:'target'})
    # c3_c4 = df[[c3, c4]].rename(columns = {c3:'source', c4:'target'})

    df_graph = pd.concat([c1_c2, c2_c3], ignore_index = True) # c3_c4
    df_graph = df_graph.query('source != "source"') # Ensure a "source" not isn't present.

    # Create weight column based on occurences of source-target pairings.
    df_graph = pd.DataFrame(df_graph.value_counts()).reset_index()
    df_graph = df_graph.rename(columns={'count':'weight'})

    # Initialize graph object.
    G = nx.from_pandas_edgelist(df_graph, 'source', 'target', 'weight')

    # Remove self-loops.
    G.remove_edges_from(nx.selfloop_edges(G))

    # Add nodes.
    nodes = list(dict.fromkeys(df_graph['source'].values.tolist() + df_graph['target'].values.tolist()))
    nodes = pd.DataFrame(nodes, columns = ['source'])
    G.add_nodes_from(nodes)

    # Set degree attributes.
    nx.set_node_attributes(G, dict(G.degree(G.nodes())), 'degree')

    # Set node type attributes.
    node_attrs = df.to_dict('list')
    node_attrs = {k: node_attrs[k] for k in (c1, c2, c3)}
    node_attrs = {v: k for k, values in node_attrs.items() for v in values}
    print (node_attrs)
    nx.set_node_attributes(G, node_attrs, 'type')

    # # Find centrality measures.
    # betweenness_dict = nx.betweenness_centrality(G)
    # eigenvector_dict = nx.eigenvector_centrality(G)
    # degree_cent_dict = nx.degree_centrality(G)

    # # Assign each centrality measure to an attribute.
    # nx.set_node_attributes(G, betweenness_dict, 'betweenness')
    # nx.set_node_attributes(G, eigenvector_dict, 'eigenvector')
    # nx.set_node_attributes(G, degree_cent_dict, 'degree_cent')

    # Declare node and edge positions with seed for reproducibility.
    pos = nx.spring_layout(G, seed=7)
    nx.set_node_attributes(G, pos, 'pos')

    # # Find communities.
    # communities = nx.community.naive_greedy_modularity_communities(G)

    # # Create a dictionary that maps nodes to their community.
    # modularity_dict = {}
    # for i, c in enumerate(communities):
    #     for name in c:
    #         modularity_dict[name] = i
    
    # nx.set_node_attributes(G, modularity_dict, 'group')

    # Double check "source" node is removed.
    G.remove_node('source')

    return (G)

G = create_network_graph(data, 'title', 'experience', 'benefit')
print (G)
# Out:
# {'Test': 'title', 'Mystery Plays': 'title', 'Oedipus': 'title', 'Me Before You': 'title', 'The Crying of Lot 49': 'title', 'Saturday': 'title', 'The Intuitionist': 'title', 'Mrs. Dalloway': 'title', 'In Search of Lost Time': 'title', 'Pilgrimage': 'title', 'Middlemarch': 'title', 'Turn of the Screw': 'title', 'The Black Cat': 'title', 'Buffy the Vampire Slayer': 'title', 'Mary Poppins': 'title', 'Horse Feathers': 'title', 'The Sandman': 'title', 'Broad City': 'title', 'Crazy Ex-Girlfriend': 'title', 'Miranda': 'title', '30 Rock': 'title', 'Don Quixote': 'title', 'Blazing Saddles': 'title', 'A Funny Thing Happened on the Way to the Forum': 'title', 'I Love Lucy': 'title', 'Lysistrata': 'title', 'The Frogs': 'title', "Gulliver's Travels": 'title', 'Bioshock': 'title', 'Persepolis 2: The Story of a Return': 'title', 'The Great Railway Bazaar: By Train Through Asia': 'title', 'The Left Hand of Darkness': 'title', 'Utopia': 'title', 'An Apology for the Life of Mrs. Shamela Andrews': 'title', 'Batrachomyomachia': 'title', 'Reader, suppose you were an idiot...': 'title', "I'm not one for tall, swaggering generals...": 'title', 'Tom Jones': 'title', 'New Atlantis': 'title', 'I Know Why the Caged Bird Sings': 'title', 'The Meditations of Marcus Aurelius': 'title', 'The Wisdom of Ptahhotep': 'title', 'Confessions': 'title', "The Hitchhiker's Guide to the Galaxy": 'title', 'Animal Farm': 'title', 'Infinite Jest': 'title', 'All about H. Hatterr': 'title', 'Babbitt': 'title', 'We': 'title', 'Meno': 'title', 'Oedipus Tyrannus': 'title', 'Zhuangzi': 'title', 'Americanah': 'title', 'Casablanca': 'title', 'The Unbearable Lightness of Being': 'title', 'Dream of the Red Chamber': 'title', 'Cloud Atlas': 'title', 'Mr. Nobody': 'title', 'Total Recall': 'title', 'Invisible Man': 'title', 'Oresteia': 'title', 'Promising Young Woman': 'title', 'Thyestes': 'title', 'Père Goriot': 'title', 'Narrative of the Life of Frederick Douglass, An American Slave': 'title', '1 Thessalonians': 'title', 'The Kesh Temple Hymn': 'title', 'Fun Home': 'title', 'Alcestis': 'title', 'The Metamorphosis': 'title', 'One Hundred Years of Solitude': 'title', 'Roma': 'title', "Pan's Labyrinth": 'title', 'Like Water for Chocolate': 'title', 'A Wild Sheep Chase': 'title', 'Beloved': 'title', 'Labyrinths': 'title', 'Becoming': 'title', 'The Autobiography of Malcolm X': 'title', 'My Bondage and My Freedom': 'title', 'A Wrinkle in Time': 'title', 'The Calcutta Chromosome': 'title', 'Bloodchild': 'title', 'Ubik': 'title', 'Naked Lunch': 'title', "One Flew over the Cuckoo's Nest": 'title', 'The Trial': 'title', 'The Scarlet Letter': 'title', 'The Yellow Wallpaper': 'title', 'The Divine Comedy': 'title', 'Superman': 'title', 'The Gold Rush': 'title', 'Graciosa and Percinet': 'title', 'The Facetious Nights of Straparola (Adamantina and the Doll)': 'title', 'The Columbian Orator': 'title', 'The Blue Fairy Book': 'title', 'Histoires ou contes du temps passé': 'title', 'Bottle Rocket': 'title', 'Frederick': 'title', 'Pippi Longstocking': 'title', 'Fox in Socks': 'title', 'Winnie the Pooh': 'title', "Alice's Adventures in Wonderland": 'title', "Mother Goose's Melody": 'title', 'The Book of Nonsense': 'title', 'Call Me By Your Name': 'title', 'The History of Love': 'title', "The Time Traveler's Wife": 'title', 'Bel Canto': 'title', 'Jane Eyre': 'title', "Sappho's Lyrics": 'title', 'Fleabag': 'title', 'My Antonia': 'title', 'A Farewell to Arms': 'title', 'here is the deepest secret nobody knows/ I carry your heart (I carry it in my heart)': 'title', 'I have tucked our love inside the lyric/ Like silver in a pocket': 'title', 'Crossing Brooklyn Ferry': 'title', 'I Should Not Dare to Leave My Friend': 'title', 'Do Not God Gentle into That Good Night': 'title', 'Chinese Ode included in the Shijing of the Five Classics': 'title', 'The Story of Job (Ludlul bēl nēmeqi)': 'title', 'Mahābhārata': 'title', 'The Westcar Papyrus': 'title', 'Toy Story': 'title', 'The Bridges of Madison County': 'title', ...
# Graph with 296 nodes and 282 edges
# CPU times: user 314 ms, sys: 18.2 ms, total: 332 ms
# Wall time: 400 ms

# %% [markdown]
# ## Plotly Network Visualization
#
# To do:
# * Associate nodes with metadata (user, experience, etc. for shape)
# * Change color scheme of network to reflect communities

# %%
# %%time

G = create_network_graph(data, 'title', 'experience', 'benefit')
G
# create_network_visualization(G)
# Out:
# {'Test': 'title', 'Mystery Plays': 'title', 'Oedipus': 'title', 'Me Before You': 'title', 'The Crying of Lot 49': 'title', 'Saturday': 'title', 'The Intuitionist': 'title', 'Mrs. Dalloway': 'title', 'In Search of Lost Time': 'title', 'Pilgrimage': 'title', 'Middlemarch': 'title', 'Turn of the Screw': 'title', 'The Black Cat': 'title', 'Buffy the Vampire Slayer': 'title', 'Mary Poppins': 'title', 'Horse Feathers': 'title', 'The Sandman': 'title', 'Broad City': 'title', 'Crazy Ex-Girlfriend': 'title', 'Miranda': 'title', '30 Rock': 'title', 'Don Quixote': 'title', 'Blazing Saddles': 'title', 'A Funny Thing Happened on the Way to the Forum': 'title', 'I Love Lucy': 'title', 'Lysistrata': 'title', 'The Frogs': 'title', "Gulliver's Travels": 'title', 'Bioshock': 'title', 'Persepolis 2: The Story of a Return': 'title', 'The Great Railway Bazaar: By Train Through Asia': 'title', 'The Left Hand of Darkness': 'title', 'Utopia': 'title', 'An Apology for the Life of Mrs. Shamela Andrews': 'title', 'Batrachomyomachia': 'title', 'Reader, suppose you were an idiot...': 'title', "I'm not one for tall, swaggering generals...": 'title', 'Tom Jones': 'title', 'New Atlantis': 'title', 'I Know Why the Caged Bird Sings': 'title', 'The Meditations of Marcus Aurelius': 'title', 'The Wisdom of Ptahhotep': 'title', 'Confessions': 'title', "The Hitchhiker's Guide to the Galaxy": 'title', 'Animal Farm': 'title', 'Infinite Jest': 'title', 'All about H. Hatterr': 'title', 'Babbitt': 'title', 'We': 'title', 'Meno': 'title', 'Oedipus Tyrannus': 'title', 'Zhuangzi': 'title', 'Americanah': 'title', 'Casablanca': 'title', 'The Unbearable Lightness of Being': 'title', 'Dream of the Red Chamber': 'title', 'Cloud Atlas': 'title', 'Mr. Nobody': 'title', 'Total Recall': 'title', 'Invisible Man': 'title', 'Oresteia': 'title', 'Promising Young Woman': 'title', 'Thyestes': 'title', 'Père Goriot': 'title', 'Narrative of the Life of Frederick Douglass, An American Slave': 'title', '1 Thessalonians': 'title', 'The Kesh Temple Hymn': 'title', 'Fun Home': 'title', 'Alcestis': 'title', 'The Metamorphosis': 'title', 'One Hundred Years of Solitude': 'title', 'Roma': 'title', "Pan's Labyrinth": 'title', 'Like Water for Chocolate': 'title', 'A Wild Sheep Chase': 'title', 'Beloved': 'title', 'Labyrinths': 'title', 'Becoming': 'title', 'The Autobiography of Malcolm X': 'title', 'My Bondage and My Freedom': 'title', 'A Wrinkle in Time': 'title', 'The Calcutta Chromosome': 'title', 'Bloodchild': 'title', 'Ubik': 'title', 'Naked Lunch': 'title', "One Flew over the Cuckoo's Nest": 'title', 'The Trial': 'title', 'The Scarlet Letter': 'title', 'The Yellow Wallpaper': 'title', 'The Divine Comedy': 'title', 'Superman': 'title', 'The Gold Rush': 'title', 'Graciosa and Percinet': 'title', 'The Facetious Nights of Straparola (Adamantina and the Doll)': 'title', 'The Columbian Orator': 'title', 'The Blue Fairy Book': 'title', 'Histoires ou contes du temps passé': 'title', 'Bottle Rocket': 'title', 'Frederick': 'title', 'Pippi Longstocking': 'title', 'Fox in Socks': 'title', 'Winnie the Pooh': 'title', "Alice's Adventures in Wonderland": 'title', "Mother Goose's Melody": 'title', 'The Book of Nonsense': 'title', 'Call Me By Your Name': 'title', 'The History of Love': 'title', "The Time Traveler's Wife": 'title', 'Bel Canto': 'title', 'Jane Eyre': 'title', "Sappho's Lyrics": 'title', 'Fleabag': 'title', 'My Antonia': 'title', 'A Farewell to Arms': 'title', 'here is the deepest secret nobody knows/ I carry your heart (I carry it in my heart)': 'title', 'I have tucked our love inside the lyric/ Like silver in a pocket': 'title', 'Crossing Brooklyn Ferry': 'title', 'I Should Not Dare to Leave My Friend': 'title', 'Do Not God Gentle into That Good Night': 'title', 'Chinese Ode included in the Shijing of the Five Classics': 'title', 'The Story of Job (Ludlul bēl nēmeqi)': 'title', 'Mahābhārata': 'title', 'The Westcar Papyrus': 'title', 'Toy Story': 'title', 'The Bridges of Madison County': 'title', ...
# CPU times: user 302 ms, sys: 8.98 ms, total: 311 ms
# Wall time: 373 ms

# %% [markdown]
# ### Create Dataframe for Plotly

# %%
# %%time

# Create visualization "traces" for edges.
def create_edge_traces(graph_object):
    # Declare Edge & Node Locations on x, y axis.
    edge_x = []
    edge_y = []
    for edge in G.edges():
        x0, y0 = G.nodes[edge[0]]['pos']
        x1, y1 = G.nodes[edge[1]]['pos']
        edge_x.append(x0)
        edge_x.append(x1)
        edge_x.append(None)
        edge_y.append(y0)
        edge_y.append(y1)
        edge_y.append(None)

    edges_df = pd.DataFrame({
        'x':edge_x,
        'y':edge_y
    })

    return edges_df

# Create visualization "traces" for nodes.
def create_node_traces(graph_object):
    node_x = []
    node_y = []
    for node in graph_object.nodes():
        x, y = graph_object.nodes[node]['pos']
        node_x.append(x)
        node_y.append(y)

    # Declare Node Attributes
    node_text = []
    node_color = []
    for node, attributes in graph_object.nodes(data=True):
        node_text.append(node)
        node_color.append(attributes['type'])

    node_size = []
    for node, adjacencies in enumerate(graph_object.adjacency()):
        node_size.append(len(adjacencies[1]) * 2)

    nodes_df = pd.DataFrame({
        'x':node_x,
        'y':node_y,
        'text':node_text,
        'type':node_color,
        'size':node_size
    })

    return nodes_df

node_traces = create_node_traces(G)
edge_traces = create_edge_traces(G)

node_traces
# Out:
# CPU times: user 3.11 ms, sys: 256 μs, total: 3.36 ms
# Wall time: 3.24 ms
#             x         y                  text        type  size
# 0   -0.218766  0.032353                  Love  experience    32
# 1   -0.207644 -0.002587              Intimacy     benefit     4
# 2    0.278087 -0.322516   Thinking "What If?"  experience    34
# 3    0.283791 -0.314188   Innovative Thinking     benefit     2
# 4   -0.343724 -0.254876            Alienation  experience    32
# ..        ...       ...                   ...         ...   ...
# 291 -0.530828 -0.111360  Anne of Green Gables       title     2
# 292 -0.545280 -0.096300              Antigone       title     2
# 293  0.054944 -0.207207               Babbitt       title     2
# 294  0.049059  1.000000     Batrachomyomachia       title     2
# 295 -0.852128 -0.091020       1 Thessalonians       title     2
#
# [296 rows x 5 columns]

# %% [markdown]
# ### Build Network Visualization

# %%
# %%time

edge_trace = go.Scatter(
    x=edge_traces['x'], y=edge_traces['y'],
    line=dict(width=0.5, color='#888'),
    hoverinfo='none',
    mode='lines')

fig = px.scatter(
    node_traces, x="x", y="y", color="type",
    size='size', hover_data=['text']
)

fig.add_traces(edge_trace)

fig
# Out:
# CPU times: user 76.2 ms, sys: 5.98 ms, total: 82.2 ms
# Wall time: 132 ms
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/Library/Python/3.13/lib/python/site-packages/IPython/core/formatters.py:984, in IPythonDisplayFormatter.__call__(self, obj)
#     982 method = get_real_method(obj, self.print_method)
#     983 if method is not None:
# --> 984     method()
#     985     return True
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/plotly/basedatatypes.py:832, in BaseFigure._ipython_display_(self)
#     829 import plotly.io as pio
#     831 if pio.renderers.render_on_display and pio.renderers.default:
# --> 832     pio.show(self)
#     833 else:
#     834     print(repr(self))
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/plotly/io/_renderers.py:394, in show(fig, renderer, validate, **kwargs)
#     389         raise ValueError(
#     390             "Mime type rendering requires ipython but it is not installed"
#     391         )
#     393     if not nbformat or Version(nbformat.__version__) < Version("4.2.0"):
# --> 394         raise ValueError(
#     395             "Mime type rendering requires nbformat>=4.2.0 but it is not installed"
#     396         )
#     398     ipython_display.display(bundle, raw=True)
#     400 # external renderers
#
# ValueError: Mime type rendering requires nbformat>=4.2.0 but it is not installed
# Figure({
#     'data': [{'customdata': array([['Love'],
#                                    ['Thinking "What If?"'],
#                                    ['Alienation'],
#                                    ['Empathy'],
#                                    ['Curiosity'],
#                                    ['Gratification'],
#                                    ['Paranoia'],
#                                    ['Self-Irony'],
#                                    ['Self-Acceptance'],
#                                    ['Courage'],
#                                    ['Identification'],
#                                    ['Relearning'],
#                                    ['Mind Wandering'],
#                                    ['Acceptance of Loss'],
#                                    ['Tranquility'],
#                                    ['Being Wrong'],
#                                    ['Generous Love'],
#                                    ['Righteousness'],
#                                    ['Suspended Judgment'],
#                                    ['Awe'],
#                                    ['Optimism'],
#                                    ['Superiority'],
#                                    ['Ready to Grow'],
#                                    ['Released Emotion Brake'],
#                                    ['Wonder'],
#                                    ['Moral Omniscience'],
#                                    ['Self-Trust'],
#                                    ['Immersion'],
#                                    ['Self-Love'],
#                                    ['Confusion'],
#                                    ['Dissociation'],
#                                    ['Distress'],
#                                    ['Double Identification'],
#                                    ['Eustress'],
#                                    ['Existential Nausea'],
#                                    ['Togetherness'],
#                                    ['Sober Uplift'],
#                                    ['Skepticism'],
#                                    ['Nimbleness'],
#                                    ['Self-Efficacy']], dtype=object),
#               'hovertemplate': ('type=experience<br>x=%{x}<br>y' ... '{customdata[0]}<extra></extra>'),
#               'legendgroup': 'experience',
#               'marker': {'color': '#636efa',
#                          'size': array([32, 34, 32, 28, 26, 28, 24, 26, 20, 18, 20, 18, 18, 12, 16, 14, 14, 12,
#                                         16, 12, 10, 10,  8,  6,  8, 10,  6,  6,  8,  6,  4,  4,  4,  4,  4,  4,
#                                          4,  4,  4,  4]),
#                          'sizemode': 'area',
#                          'sizeref': np.float64(0.085),
#                          'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'experience',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'scatter',
#               'x': array([-2.18766329e-01,  2.78087354e-01, -3.43724256e-01, -5.09370942e-01,
#                           -2.80392535e-01, -2.68357156e-01,  2.22285765e-01,  4.02286012e-02,
#                            1.82583898e-01,  2.58467611e-01,  4.18366242e-01,  1.65315236e-01,
#                           -4.27126902e-01,  3.81969563e-01, -1.78735576e-02,  8.42431893e-01,
#                           -4.93120726e-01,  4.61172004e-01, -1.26702627e-01,  7.02440435e-01,
#                           -7.70910287e-01,  6.01053797e-02,  5.77682583e-01, -3.52228640e-01,
#                            7.74995254e-01,  4.04444241e-01, -2.16711730e-01, -3.91357254e-01,
#                           -1.75055768e-01, -7.81839335e-01, -7.65925007e-05, -2.93046522e-01,
#                            5.03728554e-01,  8.25071613e-01, -2.48826746e-01, -9.16356054e-01,
#                           -4.39531179e-01,  1.61753620e-01,  6.35581263e-01, -3.67326844e-01]),
#               'xaxis': 'x',
#               'y': array([ 0.03235308, -0.32251585, -0.25487618, -0.07438239, -0.79613835,
#                            0.47837909, -0.6514226 , -0.23144338,  0.64953344, -0.03571471,
#                            0.07476874,  0.16614732,  0.72274916,  0.18631232, -0.18260577,
#                            0.27688207,  0.10145289,  0.647531  , -0.25640081,  0.18514495,
#                           -0.12546552,  0.94720035,  0.52442772,  0.37423774, -0.02409336,
#                            0.69664693, -0.35697348, -0.76696159, -0.15355928, -0.03481219,
#                           -0.28455021, -0.74692232,  0.00414694, -0.18622261, -0.36088453,
#                           -0.11234796,  0.1743165 , -0.61841359,  0.51293864,  0.19430605]),
#               'yaxis': 'y'},
#              {'customdata': array([['Intimacy'],
#                                    ['Innovative Thinking'],
#                                    ['Self-Scrutiny'],
#                                    ['Forgiveness'],
#                                    ['Purpose'],
#                                    ['Unrealistic Romantic Expectations'],
#                                    ['Vigilance'],
#                                    ['Peace of Mind'],
#                                    ['Expanded Inner List of Cultural Norms'],
#                                    ['Tend and Befriend'],
#                                    ['Connection'],
#                                    ['Creative Breakthrough'],
#                                    ['Creativity'],
#                                    ['Healthy Grief'],
#                                    ["Humility about One's Ideas"],
#                                    ['Realistic Appreciation of Love'],
#                                    ['Community'],
#                                    ['Bias Reduction'],
#                                    ['Obedience'],
#                                    ['Resilience'],
#                                    ['Anxiety'],
#                                    ['Cognitive Flexibility'],
#                                    ['Gratitude'],
#                                    ['Healing'],
#                                    ['Catastrophizing'],
#                                    ['Empowerment'],
#                                    ['Belief'],
#                                    ['Gratitude without Inferiority'],
#                                    ['Faith'],
#                                    ['Detached Self-Awareness'],
#                                    ["Humility about One's Nature"],
#                                    ['Generosity']], dtype=object),
#               'hovertemplate': ('type=benefit<br>x=%{x}<br>y=%{' ... '{customdata[0]}<extra></extra>'),
#               'legendgroup': 'benefit',
#               'marker': {'color': '#EF553B',
#                          'size': array([ 4,  2,  2,  2,  2,  2,  4,  8,  2,  2, 18,  2,  2,  2,  2,  4,  4,  4,
#                                          2, 10,  2,  4,  4,  6,  2, 12,  4,  2,  2,  2,  2,  2]),
#                          'sizemode': 'area',
#                          'sizeref': np.float64(0.085),
#                          'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'benefit',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'scatter',
#               'x': array([-0.20764439,  0.2837909 , -0.33570691, -0.50474523, -0.27109063,
#                           -0.27731513,  0.20662566, -0.00355599,  0.18353087,  0.25234081,
#                            0.43413046,  0.15194024, -0.43842887,  0.37019158,  0.86074308,
#                           -0.46898154,  0.43482181, -0.19380732,  0.70611114, -0.79173281,
#                            0.06171436,  0.58901267, -0.8449818 , -0.3170722 ,  0.37539779,
#                           -0.21523551, -0.34965722, -0.22992232,  0.80239432,  0.76083348,
#                            0.08154996,  0.69667657]),
#               'xaxis': 'x',
#               'y': array([-0.00258726, -0.31418758, -0.25987195, -0.08614671, -0.79093895,
#                            0.48303422, -0.62581178, -0.21838932,  0.63671278, -0.04470522,
#                            0.03847155,  0.16492257,  0.72071147,  0.19876645,  0.28518871,
#                            0.12110985,  0.64758693, -0.25225733,  0.1991172 , -0.09487309,
#                            0.91807223,  0.50409419, -0.10526533,  0.33941197,  0.69003503,
#                           -0.29025815, -0.7478088 , -0.31277852, -0.04322649, -0.15979385,
#                           -0.21559597, -0.01129927]),
#               'yaxis': 'y'},
#              {'customdata': array([['Hamlet'],
#                                    ["Sappho's Lyrics"],
#                                    ['One Hundred Years of Solitude'],
#                                    ...,
#                                    ['Babbitt'],
#                                    ['Batrachomyomachia'],
#                                    ['1 Thessalonians']], shape=(224, 1), dtype=object),
#               'hovertemplate': ('type=title<br>x=%{x}<br>y=%{y}' ... '{customdata[0]}<extra></extra>'),
#               'legendgroup': 'title',
#               'marker': {'color': '#00cc96',
#                          'size': array([4, 2, 2, ..., 2, 2, 2], shape=(224,)),
#                          'sizemode': 'area',
#                          'sizeref': np.float64(0.085),
#                          'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'title',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'scatter',
#               'x': array([ 0.38483313, -0.19582984,  0.14510254, ...,  0.05494411,  0.04905857,
#                           -0.85212773], shape=(224,)),
#               'xaxis': 'x',
#               'y': array([ 0.14612016,  0.03553034,  0.18329009, ..., -0.20720711,  1.        ,
#                           -0.09101953], shape=(224,)),
#               'yaxis': 'y'},
#              {'hoverinfo': 'none',
#               'line': {'color': '#888', 'width': 0.5},
#               'mode': 'lines',
#               'type': 'scatter',
#               'x': array([-0.21876633, -0.20764439,         nan, ..., -0.43312836, -0.36732684,
#                                   nan], shape=(846,)),
#               'y': array([ 0.03235308, -0.00258726,         nan, ...,  0.05538799,  0.19430605,
#                                   nan], shape=(846,))}],
#     'layout': {'legend': {'itemsizing': 'constant', 'title': {'text': 'type'}, 'tracegroupgap': 0},
#                'margin': {'t': 60},
#                'template': '...',
#                'xaxis': {'anchor': 'y', 'domain': [0.0, 1.0], 'title': {'text': 'x'}},
#                'yaxis': {'anchor': 'x', 'domain': [0.0, 1.0], 'title': {'text': 'y'}}}
# })

# %%
# %%time

# Declare Edge & Node Locations on x, y axis.
edge_x = []
edge_y = []
for edge in G.edges():
    x0, y0 = G.nodes[edge[0]]['pos']
    x1, y1 = G.nodes[edge[1]]['pos']
    edge_x.append(x0)
    edge_x.append(x1)
    edge_x.append(None)
    edge_y.append(y0)
    edge_y.append(y1)
    edge_y.append(None)

edge_trace = go.Scatter(
    x=edge_x, y=edge_y,
    line=dict(width=0.5, color='#888'),
    hoverinfo='none',
    mode='lines')

node_x = []
node_y = []
for node in G.nodes():
    x, y = G.nodes[node]['pos']
    node_x.append(x)
    node_y.append(y)

node_trace = go.Scatter(
    x=node_x, y=node_y,
    mode='markers',
    hoverinfo='text',
    marker=dict(
        showscale=True,
        # colorscale options
        #'Greys' | 'YlGnBu' | 'Greens' | 'YlOrRd' | 'Bluered' | 'RdBu' |
        #'Reds' | 'Blues' | 'Picnic' | 'Rainbow' | 'Portland' | 'Jet' |
        #'Hot' | 'Blackbody' | 'Earth' | 'Electric' | 'Viridis' |
        colorscale='Rainbow',
        reversescale=True,
        color=[],
        size=10,
        colorbar=dict(
            thickness=15,
            title=dict(
              text='Node Connections',
              side='right'
            ),
            xanchor='left',
        ),
        line_width=2))

# Declare Node Attributes
node_text = []
node_color = []
for node, attributes in G.nodes(data=True):
    node_text.append(node)
    node_color.append(attributes['type'])

node_size = []
for node, adjacencies in enumerate(G.adjacency()):
    node_size.append(len(adjacencies[1]) * 2)

# node_trace.marker.color = node_color
node_trace.marker.size = node_size
node_trace.text = node_text

# Visualize
fig = go.Figure(data=[edge_trace, node_trace],
    layout=go.Layout(
        title=dict(
            text="<br>Network graph made with Python",
            font=dict(
                size=16
            )
        ),
        showlegend=False,
        hovermode='closest',
        margin=dict(b=20,l=5,r=5,t=40),
        # annotations=[ dict(
        #     text="Python code: <a href='https://plotly.com/python/network-graphs/'> https://plotly.com/python/network-graphs/</a>",
        #     showarrow=False,
        #     xref="paper", yref="paper",
        #     x=0.005, y=-0.002 ) ],
        # xaxis=dict(showgrid=False, zeroline=False, showticklabels=False),
        # yaxis=dict(showgrid=False, zeroline=False, showticklabels=False))
        )
)

fig
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File <timed exec>:38
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/plotly/graph_objs/_scatter.py:3534, in Scatter.__init__(self, arg, alignmentgroup, cliponaxis, connectgaps, customdata, customdatasrc, dx, dy, error_x, error_y, fill, fillcolor, fillgradient, fillpattern, groupnorm, hoverinfo, hoverinfosrc, hoverlabel, hoveron, hovertemplate, hovertemplatesrc, hovertext, hovertextsrc, ids, idssrc, legend, legendgroup, legendgrouptitle, legendrank, legendwidth, line, marker, meta, metasrc, mode, name, offsetgroup, opacity, orientation, selected, selectedpoints, showlegend, stackgaps, stackgroup, stream, text, textfont, textposition, textpositionsrc, textsrc, texttemplate, texttemplatesrc, uid, uirevision, unselected, visible, x, x0, xaxis, xcalendar, xhoverformat, xperiod, xperiod0, xperiodalignment, xsrc, y, y0, yaxis, ycalendar, yhoverformat, yperiod, yperiod0, yperiodalignment, ysrc, zorder, **kwargs)
#    3532 _v = marker if marker is not None else _v
#    3533 if _v is not None:
# -> 3534     self["marker"] = _v
#    3535 _v = arg.pop("meta", None)
#    3536 _v = meta if meta is not None else _v
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/plotly/basedatatypes.py:4860, in BasePlotlyType.__setitem__(self, prop, value)
#    4858 # ### Handle compound property ###
#    4859 if isinstance(validator, CompoundValidator):
# -> 4860     self._set_compound_prop(prop, value)
#    4862 # ### Handle compound array property ###
#    4863 elif isinstance(validator, (CompoundArrayValidator, BaseDataValidator)):
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/plotly/basedatatypes.py:5271, in BasePlotlyType._set_compound_prop(self, prop, val)
#    5268 # Import value
#    5269 # ------------
#    5270 validator = self._get_validator(prop)
# -> 5271 val = validator.validate_coerce(val, skip_invalid=self._skip_invalid)
#    5273 # Save deep copies of current and new states
#    5274 # ------------------------------------------
#    5275 curr_val = self._compound_props.get(prop, None)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/_plotly_utils/basevalidators.py:2512, in CompoundValidator.validate_coerce(self, v, skip_invalid, _validate)
#    2509     v = self.data_class()
#    2511 elif isinstance(v, dict):
# -> 2512     v = self.data_class(v, skip_invalid=skip_invalid, _validate=_validate)
#    2514 elif isinstance(v, self.data_class):
#    2515     # Copy object
#    2516     v = self.data_class(v)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/plotly/graph_objs/scatter/_marker.py:1629, in Marker.__init__(self, arg, angle, angleref, anglesrc, autocolorscale, cauto, cmax, cmid, cmin, color, coloraxis, colorbar, colorscale, colorsrc, gradient, line, maxdisplayed, opacity, opacitysrc, reversescale, showscale, size, sizemin, sizemode, sizeref, sizesrc, standoff, standoffsrc, symbol, symbolsrc, **kwargs)
#    1627 _v = color if color is not None else _v
#    1628 if _v is not None:
# -> 1629     self["color"] = _v
#    1630 _v = arg.pop("coloraxis", None)
#    1631 _v = coloraxis if coloraxis is not None else _v
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/plotly/basedatatypes.py:4868, in BasePlotlyType.__setitem__(self, prop, value)
#    4864         self._set_array_prop(prop, value)
#    4866     # ### Handle simple property ###
#    4867     else:
# -> 4868         self._set_prop(prop, value)
#    4869 else:
#    4870     # Make sure properties dict is initialized
#    4871     self._init_props()
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/plotly/basedatatypes.py:5212, in BasePlotlyType._set_prop(self, prop, val)
#    5210         return
#    5211     else:
# -> 5212         raise err
#    5214 # val is None
#    5215 # -----------
#    5216 if val is None:
#    5217     # Check if we should send null update
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/plotly/basedatatypes.py:5207, in BasePlotlyType._set_prop(self, prop, val)
#    5204 validator = self._get_validator(prop)
#    5206 try:
# -> 5207     val = validator.validate_coerce(val)
#    5208 except ValueError as err:
#    5209     if self._skip_invalid:
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/_plotly_utils/basevalidators.py:1404, in ColorValidator.validate_coerce(self, v, should_raise)
#    1401 invalid_els = self.find_invalid_els(v, validated_v)
#    1403 if invalid_els and should_raise:
# -> 1404     self.raise_invalid_elements(invalid_els)
#    1405 else:
#    1406     v = validated_v
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/_plotly_utils/basevalidators.py:312, in BaseValidator.raise_invalid_elements(self, invalid_els)
#     310     def raise_invalid_elements(self, invalid_els):
#     311         if invalid_els:
# --> 312             raise ValueError(
#     313                 """
#     314     Invalid element(s) received for the '{name}' property of {pname}
#     315         Invalid elements include: {invalid}
#     316
#     317 {valid_clr_desc}""".format(
#     318                     name=self.plotly_name,
#     319                     pname=self.parent_name,
#     320                     invalid=invalid_els[:10],
#     321                     valid_clr_desc=self.description(),
#     322                 )
#     323             )
#
# ValueError:
#     Invalid element(s) received for the 'color' property of scatter.marker
#         Invalid elements include: ['experience', 'benefit', 'experience', 'benefit', 'experience', 'benefit', 'experience', 'benefit', 'experience', 'benefit']
#
#     The 'color' property is a color and may be specified as:
#       - A hex string (e.g. '#ff0000')
#       - An rgb/rgba string (e.g. 'rgb(255,0,0)')
#       - An hsl/hsla string (e.g. 'hsl(0,100%,50%)')
#       - An hsv/hsva string (e.g. 'hsv(0,100%,100%)')
#       - A named CSS color:
#             aliceblue, antiquewhite, aqua, aquamarine, azure,
#             beige, bisque, black, blanchedalmond, blue,
#             blueviolet, brown, burlywood, cadetblue,
#             chartreuse, chocolate, coral, cornflowerblue,
#             cornsilk, crimson, cyan, darkblue, darkcyan,
#             darkgoldenrod, darkgray, darkgrey, darkgreen,
#             darkkhaki, darkmagenta, darkolivegreen, darkorange,
#             darkorchid, darkred, darksalmon, darkseagreen,
#             darkslateblue, darkslategray, darkslategrey,
#             darkturquoise, darkviolet, deeppink, deepskyblue,
#             dimgray, dimgrey, dodgerblue, firebrick,
#             floralwhite, forestgreen, fuchsia, gainsboro,
#             ghostwhite, gold, goldenrod, gray, grey, green,
#             greenyellow, honeydew, hotpink, indianred, indigo,
#             ivory, khaki, lavender, lavenderblush, lawngreen,
#             lemonchiffon, lightblue, lightcoral, lightcyan,
#             lightgoldenrodyellow, lightgray, lightgrey,
#             lightgreen, lightpink, lightsalmon, lightseagreen,
#             lightskyblue, lightslategray, lightslategrey,
#             lightsteelblue, lightyellow, lime, limegreen,
#             linen, magenta, maroon, mediumaquamarine,
#             mediumblue, mediumorchid, mediumpurple,
#             mediumseagreen, mediumslateblue, mediumspringgreen,
#             mediumturquoise, mediumvioletred, midnightblue,
#             mintcream, mistyrose, moccasin, navajowhite, navy,
#             oldlace, olive, olivedrab, orange, orangered,
#             orchid, palegoldenrod, palegreen, paleturquoise,
#             palevioletred, papayawhip, peachpuff, peru, pink,
#             plum, powderblue, purple, red, rosybrown,
#             royalblue, rebeccapurple, saddlebrown, salmon,
#             sandybrown, seagreen, seashell, sienna, silver,
#             skyblue, slateblue, slategray, slategrey, snow,
#             springgreen, steelblue, tan, teal, thistle, tomato,
#             turquoise, violet, wheat, white, whitesmoke,
#             yellow, yellowgreen
#       - A number that will be interpreted as a color
#         according to scatter.marker.colorscale
#       - A list or array of any of the above

# %% [markdown]
# ## PyVis Network Visualization

# %%
# %%time

nt = Network('500px', '100%')
# nt.from_nx(graph)
nt.generate_html(local=False)

nt

# %% [markdown]
# ## Tree Map

# %%
# %%time

tree = px.data.gapminder().query("year == 2007")
tree['continent'].unique()
# Out:
# CPU times: user 4.5 ms, sys: 2.18 ms, total: 6.68 ms
# Wall time: 6.69 ms
# array(['Asia', 'Europe', 'Africa', 'Americas', 'Oceania'], dtype=object)

# %%
# %%time

fig = px.treemap(tree, path=[px.Constant("world"), 'continent', 'country'], values='pop',
                  color='lifeExp', hover_data=['iso_alpha'],
                  color_continuous_scale='RdBu',
                  color_continuous_midpoint=np.average(tree['lifeExp'], weights=tree['pop']))
                  
fig.update_layout(margin = dict(t=50, l=25, r=25, b=25))
# fig.show()
# Out:
# CPU times: user 39.9 ms, sys: 1.61 ms, total: 41.5 ms
# Wall time: 41.1 ms
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/Documents/Digital-Humanities/.venv/lib/python3.13/site-packages/IPython/core/formatters.py:922, in IPythonDisplayFormatter.__call__(self, obj)
#     920 method = get_real_method(obj, self.print_method)
#     921 if method is not None:
# --> 922     method()
#     923     return True
#
# File ~/Documents/Digital-Humanities/.venv/lib/python3.13/site-packages/plotly/basedatatypes.py:832, in BaseFigure._ipython_display_(self)
#     829 import plotly.io as pio
#     831 if pio.renderers.render_on_display and pio.renderers.default:
# --> 832     pio.show(self)
#     833 else:
#     834     print(repr(self))
#
# File ~/Documents/Digital-Humanities/.venv/lib/python3.13/site-packages/plotly/io/_renderers.py:394, in show(fig, renderer, validate, **kwargs)
#     389         raise ValueError(
#     390             "Mime type rendering requires ipython but it is not installed"
#     391         )
#     393     if not nbformat or Version(nbformat.__version__) < Version("4.2.0"):
# --> 394         raise ValueError(
#     395             "Mime type rendering requires nbformat>=4.2.0 but it is not installed"
#     396         )
#     398     ipython_display.display(bundle, raw=True)
#     400 # external renderers
#
# ValueError: Mime type rendering requires nbformat>=4.2.0 but it is not installed
# Figure({
#     'data': [{'branchvalues': 'total',
#               'customdata': array([['AFG', 43.828],
#                                    ['ALB', 76.423],
#                                    ['DZA', 72.301],
#                                    ...,
#                                    ['(?)', 77.89057081069897],
#                                    ['(?)', 81.06215400970112],
#                                    ['(?)', 68.91909251904043]], dtype=object),
#               'domain': {'x': [0.0, 1.0], 'y': [0.0, 1.0]},
#               'hovertemplate': ('labels=%{label}<br>pop=%{value' ... 'ifeExp=%{color}<extra></extra>'),
#               'ids': array(['world/Asia/Afghanistan', 'world/Europe/Albania',
#                             'world/Africa/Algeria', 'world/Africa/Angola',
#                             'world/Americas/Argentina', 'world/Oceania/Australia',
#                             'world/Europe/Austria', 'world/Asia/Bahrain', 'world/Asia/Bangladesh',
#                             'world/Europe/Belgium', 'world/Africa/Benin', 'world/Americas/Bolivia',
#                             'world/Europe/Bosnia and Herzegovina', 'world/Africa/Botswana',
#                             'world/Americas/Brazil', 'world/Europe/Bulgaria',
#                             'world/Africa/Burkina Faso', 'world/Africa/Burundi',
#                             'world/Asia/Cambodia', 'world/Africa/Cameroon', 'world/Americas/Canada',
#                             'world/Africa/Central African Republic', 'world/Africa/Chad',
#                             'world/Americas/Chile', 'world/Asia/China', 'world/Americas/Colombia',
#                             'world/Africa/Comoros', 'world/Africa/Congo, Dem. Rep.',
#                             'world/Africa/Congo, Rep.', 'world/Americas/Costa Rica',
#                             "world/Africa/Cote d'Ivoire", 'world/Europe/Croatia',
#                             'world/Americas/Cuba', 'world/Europe/Czech Republic',
#                             'world/Europe/Denmark', 'world/Africa/Djibouti',
#                             'world/Americas/Dominican Republic', 'world/Americas/Ecuador',
#                             'world/Africa/Egypt', 'world/Americas/El Salvador',
#                             'world/Africa/Equatorial Guinea', 'world/Africa/Eritrea',
#                             'world/Africa/Ethiopia', 'world/Europe/Finland', 'world/Europe/France',
#                             'world/Africa/Gabon', 'world/Africa/Gambia', 'world/Europe/Germany',
#                             'world/Africa/Ghana', 'world/Europe/Greece', 'world/Americas/Guatemala',
#                             'world/Africa/Guinea', 'world/Africa/Guinea-Bissau',
#                             'world/Americas/Haiti', 'world/Americas/Honduras',
#                             'world/Asia/Hong Kong, China', 'world/Europe/Hungary',
#                             'world/Europe/Iceland', 'world/Asia/India', 'world/Asia/Indonesia',
#                             'world/Asia/Iran', 'world/Asia/Iraq', 'world/Europe/Ireland',
#                             'world/Asia/Israel', 'world/Europe/Italy', 'world/Americas/Jamaica',
#                             'world/Asia/Japan', 'world/Asia/Jordan', 'world/Africa/Kenya',
#                             'world/Asia/Korea, Dem. Rep.', 'world/Asia/Korea, Rep.',
#                             'world/Asia/Kuwait', 'world/Asia/Lebanon', 'world/Africa/Lesotho',
#                             'world/Africa/Liberia', 'world/Africa/Libya', 'world/Africa/Madagascar',
#                             'world/Africa/Malawi', 'world/Asia/Malaysia', 'world/Africa/Mali',
#                             'world/Africa/Mauritania', 'world/Africa/Mauritius',
#                             'world/Americas/Mexico', 'world/Asia/Mongolia',
#                             'world/Europe/Montenegro', 'world/Africa/Morocco',
#                             'world/Africa/Mozambique', 'world/Asia/Myanmar', 'world/Africa/Namibia',
#                             'world/Asia/Nepal', 'world/Europe/Netherlands',
#                             'world/Oceania/New Zealand', 'world/Americas/Nicaragua',
#                             'world/Africa/Niger', 'world/Africa/Nigeria', 'world/Europe/Norway',
#                             'world/Asia/Oman', 'world/Asia/Pakistan', 'world/Americas/Panama',
#                             'world/Americas/Paraguay', 'world/Americas/Peru',
#                             'world/Asia/Philippines', 'world/Europe/Poland',
#                             'world/Europe/Portugal', 'world/Americas/Puerto Rico',
#                             'world/Africa/Reunion', 'world/Europe/Romania', 'world/Africa/Rwanda',
#                             'world/Africa/Sao Tome and Principe', 'world/Asia/Saudi Arabia',
#                             'world/Africa/Senegal', 'world/Europe/Serbia',
#                             'world/Africa/Sierra Leone', 'world/Asia/Singapore',
#                             'world/Europe/Slovak Republic', 'world/Europe/Slovenia',
#                             'world/Africa/Somalia', 'world/Africa/South Africa',
#                             'world/Europe/Spain', 'world/Asia/Sri Lanka', 'world/Africa/Sudan',
#                             'world/Africa/Swaziland', 'world/Europe/Sweden',
#                             'world/Europe/Switzerland', 'world/Asia/Syria', 'world/Asia/Taiwan',
#                             'world/Africa/Tanzania', 'world/Asia/Thailand', 'world/Africa/Togo',
#                             'world/Americas/Trinidad and Tobago', 'world/Africa/Tunisia',
#                             'world/Europe/Turkey', 'world/Africa/Uganda',
#                             'world/Europe/United Kingdom', 'world/Americas/United States',
#                             'world/Americas/Uruguay', 'world/Americas/Venezuela',
#                             'world/Asia/Vietnam', 'world/Asia/West Bank and Gaza',
#                             'world/Asia/Yemen, Rep.', 'world/Africa/Zambia',
#                             'world/Africa/Zimbabwe', 'world/Africa', 'world/Americas', 'world/Asia',
#                             'world/Europe', 'world/Oceania', 'world'], dtype=object),
#               'labels': array(['Afghanistan', 'Albania', 'Algeria', 'Angola', 'Argentina', 'Australia',
#                                'Austria', 'Bahrain', 'Bangladesh', 'Belgium', 'Benin', 'Bolivia',
#                                'Bosnia and Herzegovina', 'Botswana', 'Brazil', 'Bulgaria',
#                                'Burkina Faso', 'Burundi', 'Cambodia', 'Cameroon', 'Canada',
#                                'Central African Republic', 'Chad', 'Chile', 'China', 'Colombia',
#                                'Comoros', 'Congo, Dem. Rep.', 'Congo, Rep.', 'Costa Rica',
#                                "Cote d'Ivoire", 'Croatia', 'Cuba', 'Czech Republic', 'Denmark',
#                                'Djibouti', 'Dominican Republic', 'Ecuador', 'Egypt', 'El Salvador',
#                                'Equatorial Guinea', 'Eritrea', 'Ethiopia', 'Finland', 'France',
#                                'Gabon', 'Gambia', 'Germany', 'Ghana', 'Greece', 'Guatemala', 'Guinea',
#                                'Guinea-Bissau', 'Haiti', 'Honduras', 'Hong Kong, China', 'Hungary',
#                                'Iceland', 'India', 'Indonesia', 'Iran', 'Iraq', 'Ireland', 'Israel',
#                                'Italy', 'Jamaica', 'Japan', 'Jordan', 'Kenya', 'Korea, Dem. Rep.',
#                                'Korea, Rep.', 'Kuwait', 'Lebanon', 'Lesotho', 'Liberia', 'Libya',
#                                'Madagascar', 'Malawi', 'Malaysia', 'Mali', 'Mauritania', 'Mauritius',
#                                'Mexico', 'Mongolia', 'Montenegro', 'Morocco', 'Mozambique', 'Myanmar',
#                                'Namibia', 'Nepal', 'Netherlands', 'New Zealand', 'Nicaragua', 'Niger',
#                                'Nigeria', 'Norway', 'Oman', 'Pakistan', 'Panama', 'Paraguay', 'Peru',
#                                'Philippines', 'Poland', 'Portugal', 'Puerto Rico', 'Reunion',
#                                'Romania', 'Rwanda', 'Sao Tome and Principe', 'Saudi Arabia', 'Senegal',
#                                'Serbia', 'Sierra Leone', 'Singapore', 'Slovak Republic', 'Slovenia',
#                                'Somalia', 'South Africa', 'Spain', 'Sri Lanka', 'Sudan', 'Swaziland',
#                                'Sweden', 'Switzerland', 'Syria', 'Taiwan', 'Tanzania', 'Thailand',
#                                'Togo', 'Trinidad and Tobago', 'Tunisia', 'Turkey', 'Uganda',
#                                'United Kingdom', 'United States', 'Uruguay', 'Venezuela', 'Vietnam',
#                                'West Bank and Gaza', 'Yemen, Rep.', 'Zambia', 'Zimbabwe', 'Africa',
#                                'Americas', 'Asia', 'Europe', 'Oceania', 'world'], dtype=object),
#               'marker': {'coloraxis': 'coloraxis',
#                          'colors': array([43.828     , 76.423     , 72.301     , 42.731     , 75.32      ,
#                                           81.235     , 79.829     , 75.635     , 64.062     , 79.441     ,
#                                           56.728     , 65.554     , 74.852     , 50.728     , 72.39      ,
#                                           73.005     , 52.295     , 49.58      , 59.723     , 50.43      ,
#                                           80.653     , 44.741     , 50.651     , 78.553     , 72.961     ,
#                                           72.889     , 65.152     , 46.462     , 55.322     , 78.782     ,
#                                           48.328     , 75.748     , 78.273     , 76.486     , 78.332     ,
#                                           54.791     , 72.235     , 74.994     , 71.338     , 71.878     ,
#                                           51.579     , 58.04      , 52.947     , 79.313     , 80.657     ,
#                                           56.735     , 59.448     , 79.406     , 60.022     , 79.483     ,
#                                           70.259     , 56.007     , 46.388     , 60.916     , 70.198     ,
#                                           82.208     , 73.338     , 81.757     , 64.698     , 70.65      ,
#                                           70.964     , 59.545     , 78.885     , 80.745     , 80.546     ,
#                                           72.567     , 82.603     , 72.535     , 54.11      , 67.297     ,
#                                           78.623     , 77.588     , 71.993     , 42.592     , 45.678     ,
#                                           73.952     , 59.443     , 48.303     , 74.241     , 54.467     ,
#                                           64.164     , 72.801     , 76.195     , 66.803     , 74.543     ,
#                                           71.164     , 42.082     , 62.069     , 52.906     , 63.785     ,
#                                           79.762     , 80.204     , 72.899     , 56.867     , 46.859     ,
#                                           80.196     , 75.64      , 65.483     , 75.537     , 71.752     ,
#                                           71.421     , 71.688     , 75.563     , 78.098     , 78.746     ,
#                                           76.442     , 72.476     , 46.242     , 65.528     , 72.777     ,
#                                           63.062     , 74.002     , 42.568     , 79.972     , 74.663     ,
#                                           77.926     , 48.159     , 49.339     , 80.941     , 72.396     ,
#                                           58.556     , 39.613     , 80.884     , 81.701     , 74.143     ,
#                                           78.4       , 52.517     , 70.616     , 58.42      , 69.819     ,
#                                           73.923     , 71.777     , 51.542     , 79.425     , 78.242     ,
#                                           76.384     , 73.747     , 74.249     , 73.422     , 62.698     ,
#                                           42.384     , 43.487     , 54.56441058, 75.35668223, 69.44386304,
#                                           77.89057081, 81.06215401, 68.91909252])},
#               'name': '',
#               'parents': array(['world/Asia', 'world/Europe', 'world/Africa', 'world/Africa',
#                                 'world/Americas', 'world/Oceania', 'world/Europe', 'world/Asia',
#                                 'world/Asia', 'world/Europe', 'world/Africa', 'world/Americas',
#                                 'world/Europe', 'world/Africa', 'world/Americas', 'world/Europe',
#                                 'world/Africa', 'world/Africa', 'world/Asia', 'world/Africa',
#                                 'world/Americas', 'world/Africa', 'world/Africa', 'world/Americas',
#                                 'world/Asia', 'world/Americas', 'world/Africa', 'world/Africa',
#                                 'world/Africa', 'world/Americas', 'world/Africa', 'world/Europe',
#                                 'world/Americas', 'world/Europe', 'world/Europe', 'world/Africa',
#                                 'world/Americas', 'world/Americas', 'world/Africa', 'world/Americas',
#                                 'world/Africa', 'world/Africa', 'world/Africa', 'world/Europe',
#                                 'world/Europe', 'world/Africa', 'world/Africa', 'world/Europe',
#                                 'world/Africa', 'world/Europe', 'world/Americas', 'world/Africa',
#                                 'world/Africa', 'world/Americas', 'world/Americas', 'world/Asia',
#                                 'world/Europe', 'world/Europe', 'world/Asia', 'world/Asia',
#                                 'world/Asia', 'world/Asia', 'world/Europe', 'world/Asia',
#                                 'world/Europe', 'world/Americas', 'world/Asia', 'world/Asia',
#                                 'world/Africa', 'world/Asia', 'world/Asia', 'world/Asia', 'world/Asia',
#                                 'world/Africa', 'world/Africa', 'world/Africa', 'world/Africa',
#                                 'world/Africa', 'world/Asia', 'world/Africa', 'world/Africa',
#                                 'world/Africa', 'world/Americas', 'world/Asia', 'world/Europe',
#                                 'world/Africa', 'world/Africa', 'world/Asia', 'world/Africa',
#                                 'world/Asia', 'world/Europe', 'world/Oceania', 'world/Americas',
#                                 'world/Africa', 'world/Africa', 'world/Europe', 'world/Asia',
#                                 'world/Asia', 'world/Americas', 'world/Americas', 'world/Americas',
#                                 'world/Asia', 'world/Europe', 'world/Europe', 'world/Americas',
#                                 'world/Africa', 'world/Europe', 'world/Africa', 'world/Africa',
#                                 'world/Asia', 'world/Africa', 'world/Europe', 'world/Africa',
#                                 'world/Asia', 'world/Europe', 'world/Europe', 'world/Africa',
#                                 'world/Africa', 'world/Europe', 'world/Asia', 'world/Africa',
#                                 'world/Africa', 'world/Europe', 'world/Europe', 'world/Asia',
#                                 'world/Asia', 'world/Africa', 'world/Asia', 'world/Africa',
#                                 'world/Americas', 'world/Africa', 'world/Europe', 'world/Africa',
#                                 'world/Europe', 'world/Americas', 'world/Americas', 'world/Americas',
#                                 'world/Asia', 'world/Asia', 'world/Asia', 'world/Africa',
#                                 'world/Africa', 'world', 'world', 'world', 'world', 'world', ''],
#                                dtype=object),
#               'type': 'treemap',
#               'values': array([  31889923,    3600523,   33333216,   12420476,   40301927,   20434176,
#                                   8199783,     708573,  150448339,   10392226,    8078314,    9119152,
#                                   4552198,    1639131,  190010647,    7322858,   14326203,    8390505,
#                                  14131858,   17696293,   33390141,    4369038,   10238807,   16284741,
#                                1318683096,   44227550,     710960,   64606759,    3800610,    4133884,
#                                  18013409,    4493312,   11416987,   10228744,    5468120,     496374,
#                                   9319622,   13755680,   80264543,    6939688,     551201,    4906585,
#                                  76511887,    5238460,   61083916,    1454867,    1688359,   82400996,
#                                  22873338,   10706290,   12572928,    9947814,    1472041,    8502814,
#                                   7483763,    6980412,    9956108,     301931, 1110396331,  223547000,
#                                  69453570,   27499638,    4109086,    6426679,   58147733,    2780132,
#                                 127467972,    6053193,   35610177,   23301725,   49044790,    2505559,
#                                   3921278,    2012649,    3193942,    6036914,   19167654,   13327079,
#                                  24821286,   12031795,    3270065,    1250882,  108700891,    2874127,
#                                    684736,   33757175,   19951656,   47761980,    2055080,   28901790,
#                                  16570613,    4115771,    5675356,   12894865,  135031164,    4627926,
#                                   3204897,  169270617,    3242173,    6667147,   28674757,   91077287,
#                                  38518241,   10642836,    3942491,     798094,   22276056,    8860588,
#                                    199579,   27601038,   12267493,   10150265,    6144562,    4553009,
#                                   5447502,    2009245,    9118773,   43997828,   40448191,   20378239,
#                                  42292929,    1133066,    9031088,    7554661,   19314747,   23174294,
#                                  38139640,   65068149,    5701579,    1056608,   10276158,   71158647,
#                                  29170398,   60776238,  301139947,    3447496,   26084662,   85262356,
#                                   4018332,   22211743,   11746035,   12311143,  929539692,  898871184,
#                                3811953827,  586098529,   24549947, 6251013179])}],
#     'layout': {'coloraxis': {'cmid': np.float64(68.91909251904043),
#                              'colorbar': {'title': {'text': 'lifeExp'}},
#                              'colorscale': [[0.0, 'rgb(103,0,31)'], [0.1,
#                                             'rgb(178,24,43)'], [0.2,
#                                             'rgb(214,96,77)'], [0.3,
#                                             'rgb(244,165,130)'], [0.4,
#                                             'rgb(253,219,199)'], [0.5,
#                                             'rgb(247,247,247)'], [0.6,
#                                             'rgb(209,229,240)'], [0.7,
#                                             'rgb(146,197,222)'], [0.8,
#                                             'rgb(67,147,195)'], [0.9,
#                                             'rgb(33,102,172)'], [1.0,
#                                             'rgb(5,48,97)']]},
#                'legend': {'tracegroupgap': 0},
#                'margin': {'b': 25, 'l': 25, 'r': 25, 't': 50},
#                'template': '...'}
# })

# %%
# %%time

# groupby : source narrative, experience, benefit, reader

tree = data.groupby(['source_narrative', 'experience']).size().to_frame('count').reset_index()

fig = px.treemap(tree, path=[px.Constant("All"), 'source_narrative', 'experience'], values='count',
                  color='experience') #, hover_data=['iso_alpha'],
                #   color_continuous_s cale='RdBu',
                #   color_continuous_midpoint=np.average(tree['lifeExp'], weights=tree['pop']))
                  
fig.update_layout(margin = dict(t=50, l=25, r=25, b=25))
# Out:
# CPU times: user 30.7 ms, sys: 6.19 ms, total: 36.9 ms
# Wall time: 35.6 ms
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/Documents/Digital-Humanities/.venv/lib/python3.13/site-packages/IPython/core/formatters.py:922, in IPythonDisplayFormatter.__call__(self, obj)
#     920 method = get_real_method(obj, self.print_method)
#     921 if method is not None:
# --> 922     method()
#     923     return True
#
# File ~/Documents/Digital-Humanities/.venv/lib/python3.13/site-packages/plotly/basedatatypes.py:832, in BaseFigure._ipython_display_(self)
#     829 import plotly.io as pio
#     831 if pio.renderers.render_on_display and pio.renderers.default:
# --> 832     pio.show(self)
#     833 else:
#     834     print(repr(self))
#
# File ~/Documents/Digital-Humanities/.venv/lib/python3.13/site-packages/plotly/io/_renderers.py:394, in show(fig, renderer, validate, **kwargs)
#     389         raise ValueError(
#     390             "Mime type rendering requires ipython but it is not installed"
#     391         )
#     393     if not nbformat or Version(nbformat.__version__) < Version("4.2.0"):
# --> 394         raise ValueError(
#     395             "Mime type rendering requires nbformat>=4.2.0 but it is not installed"
#     396         )
#     398     ipython_display.display(bundle, raw=True)
#     400 # external renderers
#
# ValueError: Mime type rendering requires nbformat>=4.2.0 but it is not installed
# Figure({
#     'data': [{'branchvalues': 'total',
#               'customdata': array([['Courage'],
#                                    ['Courage'],
#                                    ['Courage'],
#                                    ['Courage'],
#                                    ['Wonder and Fear'],
#                                    ['Wonder and Fear'],
#                                    ['Wonder and Fear'],
#                                    ['Courage'],
#                                    ['Courage'],
#                                    ['Courage'],
#                                    ['Wonder and Fear'],
#                                    ['Courage'],
#                                    ['Courage'],
#                                    ['Courage'],
#                                    ['Wonder and Fear'],
#                                    ['Wonder and Fear'],
#                                    ['Courage'],
#                                    ['Wonder and Fear'],
#                                    ['Courage'],
#                                    ['Wonder and Fear'],
#                                    ['Courage'],
#                                    ['Courage'],
#                                    ['(?)']], dtype=object),
#               'domain': {'x': [0.0, 1.0], 'y': [0.0, 1.0]},
#               'hovertemplate': ('labels=%{label}<br>count=%{val' ... '{customdata[0]}<extra></extra>'),
#               'ids': array(['All/A Song of Ice and Fire/Courage',
#                             'All/A Tale of Two Cities/Courage', 'All/Beloved/Courage',
#                             'All/The Iliad/Courage', 'All/Book of the Dead/Wonder and Fear',
#                             'All/Pyramid Texts/Wonder and Fear',
#                             'All/Sanskrit Rigveda/Wonder and Fear', 'All/Peyton Place/Courage',
#                             "All/Ridley Scott's Gladiator/Courage", 'All/The Illiad/Courage',
#                             'All/Genesis/Wonder and Fear', 'All/A Song of Ice and Fire',
#                             'All/A Tale of Two Cities', 'All/Beloved', 'All/Book of the Dead',
#                             'All/Genesis', 'All/Peyton Place', 'All/Pyramid Texts',
#                             "All/Ridley Scott's Gladiator", 'All/Sanskrit Rigveda', 'All/The Iliad',
#                             'All/The Illiad', 'All'], dtype=object),
#               'labels': array(['Courage', 'Courage', 'Courage', 'Courage', 'Wonder and Fear',
#                                'Wonder and Fear', 'Wonder and Fear', 'Courage', 'Courage', 'Courage',
#                                'Wonder and Fear', 'A Song of Ice and Fire', 'A Tale of Two Cities',
#                                'Beloved', 'Book of the Dead', 'Genesis', 'Peyton Place',
#                                'Pyramid Texts', "Ridley Scott's Gladiator", 'Sanskrit Rigveda',
#                                'The Iliad', 'The Illiad', 'All'], dtype=object),
#               'marker': {'colors': [#636efa, #636efa, #636efa, #636efa, #EF553B,
#                                     #EF553B, #EF553B, #636efa, #636efa, #636efa,
#                                     #EF553B, #636efa, #636efa, #636efa, #EF553B,
#                                     #EF553B, #636efa, #EF553B, #636efa, #EF553B,
#                                     #636efa, #636efa, #00cc96]},
#               'name': '',
#               'parents': array(['All/A Song of Ice and Fire', 'All/A Tale of Two Cities', 'All/Beloved',
#                                 'All/The Iliad', 'All/Book of the Dead', 'All/Pyramid Texts',
#                                 'All/Sanskrit Rigveda', 'All/Peyton Place',
#                                 "All/Ridley Scott's Gladiator", 'All/The Illiad', 'All/Genesis', 'All',
#                                 'All', 'All', 'All', 'All', 'All', 'All', 'All', 'All', 'All', 'All',
#                                 ''], dtype=object),
#               'type': 'treemap',
#               'values': array([ 2,  2,  2,  1,  1,  2,  2,  2, 70,  1,  1,  2,  2,  2,  1,  1,  2,  2,
#                                70,  2,  1,  1, 86])}],
#     'layout': {'legend': {'tracegroupgap': 0}, 'margin': {'b': 25, 'l': 25, 'r': 25, 't': 50}, 'template': '...'}
# })

# %% [markdown]
# ## Packed Circles

# %%
# %%time

# data
# compute circle positions
circles = circlify.circlify(
    data['source_narrative'].tolist(),
    show_enclosure=False,
    target_enclosure=circlify.Circle(x=0, y=0, r=1)
)

# reverse the order of the circles to match the order of data
circles = circles[::-1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File <timed exec>:3
#
# File ~/Documents/Digital-Humanities/.venv/lib/python3.13/site-packages/circlify.py:636, in circlify(data, target_enclosure, show_enclosure, datum_field, id_field, children_field)
#     634 if target_enclosure is None:
#     635     target_enclosure = Circle(level=0, x=0.0, y=0.0, r=1.0)
# --> 636 all_circles = _circlify_level(data, target_enclosure, fields)
#     637 if show_enclosure:
#     638     all_circles.append(target_enclosure)
#
# File ~/Documents/Digital-Humanities/.venv/lib/python3.13/site-packages/circlify.py:576, in _circlify_level(data, target_enclosure, fields, level)
#     574 if not data:
#     575     return all_circles
# --> 576 circles = _handle(data, 1, fields)
#     577 packed = pack_A1_0([circle.r for circle in circles])
#     578 enclosure = enclose(packed)
#
# File ~/Documents/Digital-Humanities/.venv/lib/python3.13/site-packages/circlify.py:543, in _handle(data, level, fields)
#     541     elements.append(Circle(r=value + 0, level=level, ex=datum))
#     542     continue
# --> 543 if datum <= 0.0:
#     544     raise ValueError("input data must be positive. Found " + str(datum))
#     545 if datum <= _eps:
#
# TypeError: '<=' not supported between instances of 'str' and 'float'

# %% [markdown]
# ## Timeline

# %%
# df[pandas.notnull(df['mean'])]

data[pd.notnull(data['pubDate'])]['pubDate']
# Out:
# 1    1894-01-01 00:00:00+00:00
# 2    1894-01-01 00:00:00+00:00
# 8    1987-09-01 00:00:00+00:00
# 9    1987-09-01 00:00:00+00:00
# 10   1859-01-01 00:00:00+00:00
#                 ...
# 81   2000-05-05 00:00:00+00:00
# 82   2023-05-19 00:00:00+00:00
# 83   2000-05-19 00:00:00+00:00
# 84   1996-01-01 00:00:00+00:00
# 85   1996-01-01 00:00:00+00:00
# Name: pubDate, Length: 78, dtype: datetime64[ns, UTC]

# %%
# %%time

timeline_data = data[pd.notnull(data['pubDate'])]
# fig = px.timeline(data, x_start="pubDate", x_end="pubDate", y="occurrence_date",color="occurrence_type")

fig = px.scatter(timeline_data, x = 'pubDate', y = 'benefit', color='benefit')

# Add range slider
fig.update_layout(
    xaxis=dict(
        rangeslider=dict(
            visible=True
        ),
        type="date"
    )
)
# Out:
# CPU times: user 25.9 ms, sys: 4.62 ms, total: 30.5 ms
# Wall time: 60.9 ms
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/Documents/Digital-Humanities/.venv/lib/python3.13/site-packages/IPython/core/formatters.py:922, in IPythonDisplayFormatter.__call__(self, obj)
#     920 method = get_real_method(obj, self.print_method)
#     921 if method is not None:
# --> 922     method()
#     923     return True
#
# File ~/Documents/Digital-Humanities/.venv/lib/python3.13/site-packages/plotly/basedatatypes.py:832, in BaseFigure._ipython_display_(self)
#     829 import plotly.io as pio
#     831 if pio.renderers.render_on_display and pio.renderers.default:
# --> 832     pio.show(self)
#     833 else:
#     834     print(repr(self))
#
# File ~/Documents/Digital-Humanities/.venv/lib/python3.13/site-packages/plotly/io/_renderers.py:394, in show(fig, renderer, validate, **kwargs)
#     389         raise ValueError(
#     390             "Mime type rendering requires ipython but it is not installed"
#     391         )
#     393     if not nbformat or Version(nbformat.__version__) < Version("4.2.0"):
# --> 394         raise ValueError(
#     395             "Mime type rendering requires nbformat>=4.2.0 but it is not installed"
#     396         )
#     398     ipython_display.display(bundle, raw=True)
#     400 # external renderers
#
# ValueError: Mime type rendering requires nbformat>=4.2.0 but it is not installed
# Figure({
#     'data': [{'hovertemplate': 'benefit=%{y}<br>pubDate=%{x}<extra></extra>',
#               'legendgroup': 'Obedience',
#               'marker': {'color': '#636efa', 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'Obedience',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'scatter',
#               'x': array([datetime.datetime(1894, 1, 1, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(1894, 1, 1, 0, 0, tzinfo=datetime.timezone.utc)],
#                          dtype=object),
#               'xaxis': 'x',
#               'y': array(['Obedience', 'Obedience'], dtype=object),
#               'yaxis': 'y'},
#              {'hovertemplate': 'benefit=%{y}<br>pubDate=%{x}<extra></extra>',
#               'legendgroup': 'Tend and Befriend',
#               'marker': {'color': '#EF553B', 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'Tend and Befriend',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'scatter',
#               'x': array([datetime.datetime(1987, 9, 1, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(1987, 9, 1, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(1859, 1, 1, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(1859, 1, 1, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2000, 1, 1, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2000, 5, 19, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2000, 1, 1, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2000, 5, 5, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2000, 5, 19, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2000, 5, 25, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2023, 5, 19, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2000, 1, 1, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2000, 5, 5, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2000, 5, 19, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2023, 5, 19, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2000, 5, 5, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2000, 5, 19, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2000, 5, 25, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2023, 5, 19, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2000, 5, 25, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2000, 5, 19, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2000, 5, 5, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2000, 5, 25, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2000, 5, 25, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2000, 1, 1, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2000, 5, 5, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2000, 5, 25, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2000, 5, 19, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2000, 1, 1, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2023, 5, 19, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2000, 5, 19, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2000, 1, 1, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2000, 5, 19, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2023, 5, 19, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2000, 5, 5, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2000, 1, 1, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2000, 5, 25, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2023, 5, 19, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2000, 1, 1, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2000, 5, 5, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2000, 5, 25, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2000, 5, 19, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2023, 5, 19, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2000, 5, 5, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2000, 1, 1, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2000, 5, 25, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2023, 5, 19, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2000, 5, 19, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2023, 5, 19, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2000, 5, 25, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2000, 1, 1, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2000, 1, 1, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2000, 5, 25, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2000, 5, 5, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2000, 5, 19, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2000, 1, 1, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2023, 5, 19, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2000, 5, 19, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2023, 5, 19, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2000, 5, 5, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2000, 5, 19, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2023, 5, 19, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2000, 5, 5, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2000, 1, 1, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2000, 5, 25, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2000, 5, 5, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2000, 5, 25, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2023, 5, 19, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2000, 5, 5, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2000, 1, 1, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2000, 5, 25, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2000, 5, 5, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2023, 5, 19, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2000, 5, 19, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(1996, 1, 1, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(1996, 1, 1, 0, 0, tzinfo=datetime.timezone.utc)],
#                          dtype=object),
#               'xaxis': 'x',
#               'y': array(['Tend and Befriend', 'Tend and Befriend', 'Tend and Befriend',
#                           'Tend and Befriend', 'Tend and Befriend', 'Tend and Befriend',
#                           'Tend and Befriend', 'Tend and Befriend', 'Tend and Befriend',
#                           'Tend and Befriend', 'Tend and Befriend', 'Tend and Befriend',
#                           'Tend and Befriend', 'Tend and Befriend', 'Tend and Befriend',
#                           'Tend and Befriend', 'Tend and Befriend', 'Tend and Befriend',
#                           'Tend and Befriend', 'Tend and Befriend', 'Tend and Befriend',
#                           'Tend and Befriend', 'Tend and Befriend', 'Tend and Befriend',
#                           'Tend and Befriend', 'Tend and Befriend', 'Tend and Befriend',
#                           'Tend and Befriend', 'Tend and Befriend', 'Tend and Befriend',
#                           'Tend and Befriend', 'Tend and Befriend', 'Tend and Befriend',
#                           'Tend and Befriend', 'Tend and Befriend', 'Tend and Befriend',
#                           'Tend and Befriend', 'Tend and Befriend', 'Tend and Befriend',
#                           'Tend and Befriend', 'Tend and Befriend', 'Tend and Befriend',
#                           'Tend and Befriend', 'Tend and Befriend', 'Tend and Befriend',
#                           'Tend and Befriend', 'Tend and Befriend', 'Tend and Befriend',
#                           'Tend and Befriend', 'Tend and Befriend', 'Tend and Befriend',
#                           'Tend and Befriend', 'Tend and Befriend', 'Tend and Befriend',
#                           'Tend and Befriend', 'Tend and Befriend', 'Tend and Befriend',
#                           'Tend and Befriend', 'Tend and Befriend', 'Tend and Befriend',
#                           'Tend and Befriend', 'Tend and Befriend', 'Tend and Befriend',
#                           'Tend and Befriend', 'Tend and Befriend', 'Tend and Befriend',
#                           'Tend and Befriend', 'Tend and Befriend', 'Tend and Befriend',
#                           'Tend and Befriend', 'Tend and Befriend', 'Tend and Befriend',
#                           'Tend and Befriend', 'Tend and Befriend', 'Tend and Befriend',
#                           'Tend and Befriend'], dtype=object),
#               'yaxis': 'y'}],
#     'layout': {'legend': {'title': {'text': 'benefit'}, 'tracegroupgap': 0},
#                'margin': {'t': 60},
#                'template': '...',
#                'xaxis': {'anchor': 'y',
#                          'domain': [0.0, 1.0],
#                          'rangeslider': {'visible': True},
#                          'title': {'text': 'pubDate'},
#                          'type': 'date'},
#                'yaxis': {'anchor': 'x',
#                          'categoryarray': [Tend and Befriend, Obedience],
#                          'categoryorder': 'array',
#                          'domain': [0.0, 1.0],
#                          'title': {'text': 'benefit'}}}
# })
